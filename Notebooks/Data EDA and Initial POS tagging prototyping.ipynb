# %% [markdown]
# Sections:
# 1. EDA
# 2. NLP on whole corpus
# 3. NER Prototypiong
# 4. Sentiment Prototyping
#
#
# # 1. EDA

# %% [markdown]
# This workbook contains mostly EDA and an introduction to the NYT corpus we are working with. In addition, we prototype the mechanisms for NER which we will use to analyse individual teams and players for further analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from collections import Counter
from textblob import TextBlob, Word
import nltk
from nltk.corpus import stopwords
import string
import spacy

# %%
# %matplotlib inline

# %%
articles_list = pd.read_csv('../nyt_scrape/nyt_article_list.csv')

# %%
articles_list['title'] = articles_list.article_urls.map(lambda x : x.split('/')[-1].split('.')[0])

# %%
articles_list.head()
# Out:
#              published_date  \
# 0  2018-06-09T17:31:27+0000
# 1  2018-06-09T01:26:37+0000
# 2  2018-06-08T22:00:03+0000
# 3  2018-06-08T17:33:17+0000
# 4  2018-06-08T13:16:38+0000
#
#                                         article_urls  \
# 0  https://www.nytimes.com/2018/06/09/sports/nba-...
# 1  https://www.nytimes.com/2018/06/08/movies/kyri...
# 2  https://www.nytimes.com/2018/06/08/sports/nba-...
# 3  https://www.nytimes.com/2018/06/08/sports/lebr...
# 4  https://www.nytimes.com/2018/06/08/sports/game...
#
#                                      article_summary  \
# 0  Accused of making the sport uncompetitive, the...
# 1  In his most extensive comments to date, the Bo...
# 2  Kevin Durant was named the finals’ M.V.P. agai...
# 3  If James wants to beat the Warriors, he may ne...
# 4  The animated show combining elements of “Game ...
#
#                                     article_headline  \
# 0      The Warriors Were Dominant. But How Dominant?
# 1  Kyrie Irving Doesn’t Know if the Earth Is Roun...
# 2  Warriors, in Full Dynasty Mode, Sweep Cavalier...
# 3  LeBron James Reveals an Injury, but His Destin...
# 4  The ‘Game of Zones’ Guys Knew You Wanted a Bry...
#
#                             title
# 0                nba-finals-sweep
# 1  kyrie-irving-nba-celtics-earth
# 2        nba-finals-warriors-cavs
# 3        lebron-james-free-agency
# 4                   game-of-zones

# %%
dir_list = os.listdir('../nyt_scrape/articles')
dir_list_split = [name.split('_')[0] for name in dir_list]

# %% [markdown]
# Checking that two article indices of same length:

# %%
assert len(articles_list) == len(dir_list_split)

# %% [markdown]
# Total articles:

# %%
print(len(articles_list))
# Out:
# 320

# %% [markdown]
# Sample article:

# %%
with open('../nyt_scrape/articles/'+np.random.choice(dir_list)) as f:
    print(f.read()[:1000],'...')
# Out:
# Kristaps Porzingis scored a career-high 38 points and Kyle O’Quinn added 15 points and 12 rebounds to help the Knicks beat the Denver Nuggets, 116-110, at Madison Square Garden on Monday night.
# Tim Hardaway Jr. scored all 13 of his points in the fourth quarter after the Knicks had blown all of their 23-point third-quarter lead.
# Nikola Jokic led the Nuggets with 28 points and Jamal Murray scored 20.
# The Knicks had taken their biggest lead of the game, 69-46, on Courtney Lee’s layup with 10 minutes 38 seconds left in the third quarter. However, the Nuggets responded by scoring the next 13 points to ignite a 27-2 run, and they took their first lead, 73-71, on Wilson Chandler’s free throws with 4:42 left in the third quarter.
# The Knicks committed 10 turnovers during that six-minute stretch.
# The game was tied 77-77 when Doug McDermott’s 3-pointer put the Knicks back in front for good with 1:09 left in the third.
# The Knicks led 84-81 going into the final quarter.
# Will Barton brought the Nugg ...

# %% [markdown]
# Parse dates:

# %%
articles_list['date'] = articles_list.published_date.apply(lambda x : x.split('T')[0])

# %%
articles_list.date = pd.to_datetime(articles_list.date)

# %% [markdown]
# Rewrite this to csv for convenience next time:

# %%
articles_list.to_csv('../nyt_scrape/articles_list_w_date.csv',index=False)

# %% [markdown]
# # 2. NLP on whole Corpus:

# %%
corpus = ''

for article in dir_list:
    with open(f'../nyt_scrape/articles/{article}') as f:
        corpus += f.read()
        corpus += '\n'

corpus = corpus.replace('’','').replace('”','').replace('“','').replace('—','')

# %% [markdown]
# Approximate number of words per article (assuming 6 characters per word):

# %%
len(corpus)/(len(dir_list)*6)
# Out:
# 797.4786458333333

# %% [markdown]
# Word frequencies:

# %%
corpus_blob = TextBlob(corpus)

# %%
corpus_words = corpus_blob.words
corpus_words = [word.lower() for word in corpus_words if word.lower() not in stopwords.words('english')\
                                                         and word not in string.punctuation]
c = Counter(corpus_words)

# %%
c.most_common()
# Out:
# [('said', 1583),
#  ('game', 1358),
#  ('points', 962),
#  ('team', 933),
#  ('season', 844),
#  ('n.b.a', 731),
#  ('one', 700),
#  ('first', 663),
#  ('james', 633),
#  ('players', 602),
#  ('knicks', 590),
#  ('two', 529),
#  ('coach', 524),
#  ('warriors', 521),
#  ('games', 514),
#  ('would', 513),
#  ('like', 508),
#  ('last', 479),
#  ('teams', 463),
#  ('time', 454),
#  ('basketball', 451),
#  ('new', 431),
#  ('play', 404),
#  ('league', 385),
#  ('cavaliers', 370),
#  ('player', 366),
#  ('back', 351),
#  ('even', 349),
#  ('night', 348),
#  ('made', 347),
#  ('years', 346),
#  ('also', 340),
#  ('could', 333),
#  ('get', 321),
#  ('three', 308),
#  ('golden', 308),
#  ('going', 306),
#  ('left', 304),
#  ('celtics', 302),
#  ('rockets', 298),
#  ('quarter', 294),
#  ('state', 290),
#  ('rebounds', 288),
#  ('much', 281),
#  ('series', 280),
#  ('way', 279),
#  ('conference', 278),
#  ('lead', 276),
#  ('year', 270),
#  ('scored', 264),
#  ('cleveland', 264),
#  ('second', 263),
#  ('played', 258),
#  ('finals', 258),
#  ('minutes', 258),
#  ('ball', 249),
#  ('still', 248),
#  ('mr', 248),
#  ('win', 247),
#  ('got', 242),
#  ('think', 240),
#  ('go', 237),
#  ('four', 233),
#  ('shot', 231),
#  ('houston', 231),
#  ('dont', 230),
#  ('guard', 228),
#  ('make', 222),
#  ('porzingis', 222),
#  ('seasons', 218),
#  ('good', 218),
#  ('career', 213),
#  ('home', 213),
#  ('boston', 213),
#  ('many', 211),
#  ('right', 210),
#  ('best', 209),
#  ('well', 208),
#  ('curry', 207),
#  ('point', 207),
#  ('hes', 206),
#  ('im', 206),
#  ('since', 205),
#  ('playing', 205),
#  ('third', 203),
#  ('playoffs', 201),
#  ('thats', 200),
#  ('assists', 199),
#  ('long', 198),
#  ('76ers', 196),
#  ('10', 196),
#  ('people', 196),
#  ('court', 193),
#  ('big', 192),
#  ('five', 190),
#  ('playoff', 189),
#  ('lebron', 189),
#  ('know', 188),
#  ('led', 186),
#  ('draft', 186),
#  ('another', 184),
#  ('next', 180),
#  ('added', 180),
#  ('former', 179),
#  ('came', 178),
#  ('fourth', 177),
#  ('half', 174),
#  ('durant', 173),
#  ('1', 173),
#  ('lot', 173),
#  ('around', 172),
#  ('start', 171),
#  ('run', 171),
#  ('come', 170),
#  ('take', 169),
#  ('top', 168),
#  ('never', 167),
#  ('paul', 166),
#  ('harden', 166),
#  ('trade', 165),
#  ('free', 163),
#  ('3', 162),
#  ('went', 161),
#  ('3-point', 158),
#  ('all-star', 156),
#  ('victory', 156),
#  ('seconds', 156),
#  ('really', 155),
#  ('shooting', 154),
#  ('without', 154),
#  ('something', 154),
#  ('record', 154),
#  ('sports', 154),
#  ('took', 153),
#  ('end', 153),
#  ('raptors', 153),
#  ('city', 153),
#  ('center', 149),
#  ('nets', 147),
#  ('put', 146),
#  ('injury', 146),
#  ('great', 145),
#  ('didnt', 145),
#  ('philadelphia', 144),
#  ('green', 144),
#  ('want', 144),
#  ('high', 143),
#  ('better', 143),
#  ('shots', 143),
#  ('see', 143),
#  ('day', 140),
#  ('final', 139),
#  ('fans', 139),
#  ('us', 138),
#  ('every', 138),
#  ('away', 138),
#  ('though', 138),
#  ('kerr', 137),
#  ('11', 136),
#  ('7', 136),
#  ('pick', 136),
#  ('early', 136),
#  ('percent', 136),
#  ('‘', 135),
#  ('president', 135),
#  ('young', 135),
#  ('brown', 135),
#  ('school', 134),
#  ('forward', 134),
#  ('times', 133),
#  ('championship', 132),
#  ('york', 131),
#  ('love', 131),
#  ('leagues', 131),
#  ('irving', 131),
#  ('part', 130),
#  ('15', 129),
#  ('six', 129),
#  ('say', 128),
#  ('told', 127),
#  ('college', 126),
#  ('monday', 125),
#  ('seven', 125),
#  ('coaches', 125),
#  ('12', 124),
#  ('lost', 124),
#  ('kevin', 124),
#  ('may', 124),
#  ('5', 123),
#  ('los', 123),
#  ('embiid', 122),
#  ('angeles', 120),
#  ('summer', 119),
#  ('work', 119),
#  ('anthony', 118),
#  ('things', 118),
#  ('bench', 116),
#  ('3-pointer', 116),
#  ('room', 116),
#  ('far', 116),
#  ('least', 115),
#  ('making', 115),
#  ('yet', 115),
#  ('missed', 114),
#  ('eastern', 114),
#  ('wednesday', 114),
#  ('help', 113),
#  ('franchise', 113),
#  ('n.b.a.s', 112),
#  ('trying', 112),
#  ('might', 112),
#  ('star', 111),
#  ('defense', 111),
#  ('finished', 111),
#  ('2', 111),
#  ('later', 111),
#  ('rookie', 111),
#  ('news', 111),
#  ('days', 110),
#  ('scoring', 110),
#  ('thursday', 110),
#  ('enough', 110),
#  ('history', 109),
#  ('recent', 108),
#  ('straight', 108),
#  ('spurs', 108),
#  ('including', 107),
#  ('13', 107),
#  ('pelicans', 107),
#  ('20', 107),
#  ('san', 107),
#  ('head', 106),
#  ('teammates', 106),
#  ('key', 105),
#  ('getting', 104),
#  ('thompson', 104),
#  ('tuesday', 103),
#  ('little', 103),
#  ('lakers', 103),
#  ('thomas', 102),
#  ('youre', 101),
#  ('saturday', 101),
#  ('states', 101),
#  ('ever', 101),
#  ('3-pointers', 100),
#  ('always', 100),
#  ('feel', 100),
#  ('hard', 100),
#  ('winning', 100),
#  ('wanted', 99),
#  ('late', 99),
#  ('toronto', 99),
#  ('man', 99),
#  ('6', 99),
#  ('clippers', 99),
#  ('past', 98),
#  ('week', 98),
#  ('different', 98),
#  ('beat', 97),
#  ('world', 96),
#  ('postseason', 95),
#  ('14', 95),
#  ('defensive', 95),
#  ('offense', 95),
#  ('guys', 95),
#  ('future', 94),
#  ('floor', 94),
#  ('friday', 94),
#  ('score', 94),
#  ('16', 93),
#  ('4', 93),
#  ('eight', 93),
#  ('become', 93),
#  ('several', 93),
#  ('basket', 93),
#  ('interview', 92),
#  ('thing', 92),
#  ('general', 92),
#  ('loss', 92),
#  ('west', 92),
#  ('roster', 92),
#  ('keep', 91),
#  ('8', 91),
#  ('pacers', 91),
#  ('look', 91),
#  ('orleans', 90),
#  ('started', 90),
#  ('called', 90),
#  ('behind', 90),
#  ('regular', 89),
#  ('17', 89),
#  ('jordan', 89),
#  ('asked', 88),
#  ('hit', 88),
#  ('life', 87),
#  ('knee', 87),
#  ('19', 87),
#  ('garden', 87),
#  ('return', 86),
#  ('line', 86),
#  ('consecutive', 86),
#  ('losing', 86),
#  ('halftime', 85),
#  ('18', 85),
#  ('manager', 85),
#  ('cant', 85),
#  ('hardaway', 85),
#  ('ive', 84),
#  ('antonio', 84),
#  ('despite', 84),
#  ('steve', 83),
#  ('sunday', 83),
#  ('show', 83),
#  ('jamess', 83),
#  ('nearly', 82),
#  ('round', 82),
#  ('ago', 82),
#  ('smith', 82),
#  ('anything', 81),
#  ('30', 81),
#  ('everything', 81),
#  ('already', 80),
#  ('arena', 80),
#  ('coming', 80),
#  ('george', 80),
#  ('course', 80),
#  ('road', 79),
#  ('able', 79),
#  ('kind', 79),
#  ('became', 79),
#  ('simmons', 79),
#  ('22', 79),
#  ('often', 79),
#  ('whose', 78),
#  ('western', 78),
#  ('streak', 78),
#  ('job', 78),
#  ('chris', 78),
#  ('months', 78),
#  ('deal', 78),
#  ('set', 77),
#  ('helped', 77),
#  ('washington', 77),
#  ('seemed', 77),
#  ('2016', 77),
#  ('dantoni', 77),
#  ('field', 77),
#  ('coaching', 76),
#  ('stars', 76),
#  ('heat', 76),
#  ('21', 75),
#  ('taking', 75),
#  ('miami', 75),
#  ('doesnt', 75),
#  ('need', 75),
#  ('media', 75),
#  ('stephen', 74),
#  ('9', 74),
#  ('almost', 74),
#  ('jr', 74),
#  ('oklahoma', 74),
#  ('million', 74),
#  ('perhaps', 74),
#  ('thought', 73),
#  ('found', 73),
#  ('try', 73),
#  ('rest', 73),
#  ('used', 73),
#  ('national', 73),
#  ('change', 73),
#  ('known', 73),
#  ('give', 73),
#  ('according', 73),
#  ('close', 73),
#  ('expected', 72),
#  ('starting', 71),
#  ('throws', 71),
#  ('kristaps', 71),
#  ('michael', 71),
#  ('pass', 71),
#  ('university', 71),
#  ('especially', 70),
#  ('along', 70),
#  ('jackson', 70),
#  ('chance', 70),
#  ('face', 70),
#  ('sure', 69),
#  ('contract', 69),
#  ('w.n.b.a', 69),
#  ('place', 68),
#  ('role', 68),
#  ('practice', 68),
#  ('level', 68),
#  ('looked', 68),
#  ('process', 68),
#  ('locker', 68),
#  ('wasnt', 68),
#  ('theres', 68),
#  ('nine', 67),
#  ('dunk', 67),
#  ('thunder', 67),
#  ('bryant', 67),
#  ('watch', 67),
#  ('dallas', 67),
#  ('guy', 67),
#  ('lee', 67),
#  ('plays', 66),
#  ('23', 66),
#  ('jeff', 66),
#  ('father', 66),
#  ('gordon', 66),
#  ('executive', 66),
#  ('month', 65),
#  ('reporters', 65),
#  ('jazz', 65),
#  ('talent', 65),
#  ('find', 65),
#  ('black', 65),
#  ('feet', 65),
#  ('matter', 65),
#  ('assistant', 65),
#  ('26', 64),
#  ('davis', 64),
#  ('less', 64),
#  ('ahead', 64),
#  ('family', 64),
#  ('hornacek', 64),
#  ('opportunity', 63),
#  ('first-round', 63),
#  ('mike', 63),
#  ('theyre', 63),
#  ('statement', 63),
#  ('soon', 62),
#  ('old', 62),
#  ('done', 62),
#  ('title', 62),
#  ('28', 62),
#  ('attempts', 62),
#  ('gave', 62),
#  ('per', 62),
#  ('cavs', 62),
#  ('bucks', 62),
#  ('actually', 62),
#  ('likely', 62),
#  ('else', 62),
#  ('seen', 62),
#  ('bad', 62),
#  ('leading', 61),
#  ('move', 61),
#  ('wizards', 61),
#  ('given', 61),
#  ('russell', 61),
#  ('wade', 61),
#  ('among', 61),
#  ('talk', 61),
#  ('range', 61),
#  ('everyone', 61),
#  ('pretty', 61),
#  ('looking', 60),
#  ('group', 60),
#  ('front', 60),
#  ('minnesota', 60),
#  ('hayward', 60),
#  ('kanter', 60),
#  ('mavericks', 60),
#  ('wants', 60),
#  ('named', 60),
#  ('business', 59),
#  ('lineup', 59),
#  ('probably', 59),
#  ('needed', 59),
#  ('together', 59),
#  ('milwaukee', 59),
#  ('ntilikina', 59),
#  ('lue', 59),
#  ('ended', 58),
#  ('within', 58),
#  ('utah', 58),
#  ('important', 58),
#  ('25', 58),
#  ('2014', 58),
#  ('turned', 58),
#  ('outside', 58),
#  ('june', 57),
#  ('felt', 57),
#  ('sixers', 57),
#  ('kyrie', 57),
#  ('knew', 57),
#  ('began', 57),
#  ('announced', 57),
#  ('griffin', 57),
#  ('short', 56),
#  ('instead', 56),
#  ('saying', 56),
#  ('performance', 56),
#  ('liberty', 56),
#  ('maybe', 56),
#  ('bit', 55),
#  ('nothing', 55),
#  ('kyle', 55),
#  ('open', 55),
#  ('real', 55),
#  ('age', 55),
#  ('white', 55),
#  ('clevelands', 55),
#  ('video', 55),
#  ('call', 54),
#  ('hall', 54),
#  ('comes', 54),
#  ('rondo', 54),
#  ('side', 54),
#  ('wins', 54),
#  ('case', 53),
#  ('redick', 53),
#  ('moment', 53),
#  ('cousins', 53),
#  ('east', 53),
#  ('says', 53),
#  ('tell', 53),
#  ('office', 53),
#  ('chicago', 53),
#  ('averaged', 52),
#  ('full', 52),
#  ('injuries', 52),
#  ('foul', 52),
#  ('deficit', 52),
#  ('averaging', 52),
#  ('timberwolves', 52),
#  ('fun', 52),
#  ('kings', 52),
#  ('athletes', 52),
#  ('j', 51),
#  ('2015', 51),
#  ('missing', 51),
#  ('finally', 51),
#  ('true', 51),
#  ('success', 51),
#  ('let', 51),
#  ('teammate', 51),
#  ('july', 51),
#  ('layup', 50),
#  ('sometimes', 50),
#  ('spent', 50),
#  ('working', 50),
#  ('seem', 50),
#  ('worked', 50),
#  ('owner', 50),
#  ('money', 50),
#  ('status', 50),
#  ('watching', 49),
#  ('24', 49),
#  ('fact', 49),
#  ('advantage', 49),
#  ('potential', 49),
#  ('weeks', 49),
#  ('rozier', 49),
#  ('horford', 49),
#  ('•', 49),
#  ('capela', 49),
#  ('shoot', 49),
#  ('police', 49),
#  ('building', 48),
#  ('valuable', 48),
#  ('weve', 48),
#  ('break', 48),
#  ('stay', 48),
#  ('johnson', 48),
#  ('whether', 48),
#  ('square', 48),
#  ('mean', 48),
#  ('anyone', 48),
#  ('adams', 48),
#  ('fultz', 48),
#  ('believe', 48),
#  ('staff', 48),
#  ('possible', 48),
#  ('tim', 48),
#  ('magic', 48),
#  ('sense', 47),
#  ('story', 47),
#  ('trip', 47),
#  ('stretch', 47),
#  ('joel', 47),
#  ('westbrook', 47),
#  ('indiana', 47),
#  ('espn', 47),
#  ('williams', 47),
#  ('p.m', 47),
#  ('tied', 47),
#  ('tried', 47),
#  ('brought', 47),
#  ('art', 47),
#  ('veteran', 47),
#  ('memphis', 47),
#  ('earlier', 47),
#  ('someone', 47),
#  ('happened', 46),
#  ('quickly', 46),
#  ('miss', 46),
#  ('biggest', 46),
#  ('power', 46),
#  ('taken', 46),
#  ('american', 46),
#  ('recently', 46),
#  ('remaining', 46),
#  ('butler', 46),
#  ('award', 45),
#  ('returned', 45),
#  ('27', 45),
#  ('situation', 45),
#  ('reason', 45),
#  ('madison', 45),
#  ('idea', 45),
#  ('experience', 45),
#  ('knows', 45),
#  ('rather', 45),
#  ('offensive', 45),
#  ('near', 45),
#  ('draymond', 44),
#  ('held', 44),
#  ('portland', 44),
#  ('period', 44),
#  ('blazers', 44),
#  ('words', 44),
#  ('ill', 44),
#  ('giving', 44),
#  ('fan', 44),
#  ('difficult', 44),
#  ('continue', 44),
#  ('makes', 43),
#  ('house', 43),
#  ('professional', 43),
#  ('klay', 43),
#  ('crowd', 43),
#  ('popovich', 43),
#  ('john', 43),
#  ('ankle', 43),
#  ('name', 43),
#  ('number', 43),
#  ('small', 43),
#  ('overall', 43),
#  ('33', 42),
#  ('injured', 42),
#  ('derozan', 42),
#  ('major', 42),
#  ('hope', 42),
#  ('eventually', 42),
#  ('mark', 42),
#  ('cut', 42),
#  ('gets', 42),
#  ('mitchell', 42),
#  ('tatum', 42),
#  ('decision', 42),
#  ('clear', 42),
#  ('easy', 42),
#  ('silver', 42),
#  ('quite', 42),
#  ('29', 42),
#  ('hill', 42),
#  ('leg', 42),
#  ('contest', 42),
#  ('tournament', 42),
#  ('whole', 42),
#  ('traded', 41),
#  ('championships', 41),
#  ('throughout', 41),
#  ('oladipo', 41),
#  ('television', 41),
#  ('sort', 41),
#  ('social', 41),
#  ('post', 41),
#  ('mexico', 41),
#  ('united', 41),
#  ('development', 41),
#  ('step', 41),
#  ('everybody', 41),
#  ('twitter', 41),
#  ('suns', 41),
#  ('schools', 41),
#  ('picks', 41),
#  ('overtime', 41),
#  ('houstons', 41),
#  ('st', 41),
#  ('saw', 40),
#  ('iguodala', 40),
#  ('body', 40),
#  ('nights', 40),
#  ('longer', 40),
#  ('officials', 40),
#  ('current', 40),
#  ('sport', 40),
#  ('forced', 40),
#  ('moving', 40),
#  ('ms', 40),
#  ('longtime', 39),
#  ('kept', 39),
#  ('seems', 39),
#  ('couldnt', 39),
#  ('others', 39),
#  ('lowry', 39),
#  ('tough', 39),
#  ('off-season', 39),
#  ('appeared', 39),
#  ('beyond', 39),
#  ('david', 39),
#  ('association', 39),
#  ('leave', 39),
#  ('2017', 39),
#  ('morning', 39),
#  ('received', 39),
#  ('n.c.a.a', 39),
#  ('position', 39),
#  ('person', 39),
#  ('bring', 38),
#  ('special', 38),
#  ('phoenix', 38),
#  ('showed', 38),
#  ('combined', 38),
#  ('absence', 38),
#  ('following', 38),
#  ('huge', 38),
#  ('issues', 38),
#  ('public', 38),
#  ('nuggets', 38),
#  ('included', 38),
#  ('entire', 38),
#  ('youve', 38),
#  ('force', 38),
#  ('stevens', 38),
#  ('okafor', 38),
#  ('sent', 37),
#  ('pro', 37),
#  ('ready', 37),
#  ('approach', 37),
#  ('sat', 37),
#  ('director', 37),
#  ('minute', 37),
#  ('members', 37),
#  ('sacramento', 37),
#  ('detroit', 37),
#  ('pistons', 37),
#  ('wife', 37),
#  ('spot', 37),
#  ('organization', 37),
#  ('trump', 37),
#  ('figure', 36),
#  ('brooklyn', 36),
#  ('opening', 36),
#  ('coached', 36),
#  ('consider', 36),
#  ('entering', 36),
#  ('gone', 36),
#  ('effort', 36),
#  ('march', 36),
#  ('stage', 36),
#  ('ben', 36),
#  ('host', 36),
#  ('jumper', 36),
#  ('challenge', 36),
#  ('use', 36),
#  ('build', 36),
#  ('joined', 36),
#  ('onto', 36),
#  ('denver', 36),
#  ('terms', 36),
#  ('strong', 36),
#  ('fit', 36),
#  ('son', 36),
#  ('built', 35),
#  ('focus', 35),
#  ('involved', 35),
#  ('turn', 35),
#  ('area', 35),
#  ('care', 35),
#  ('means', 35),
#  ('newcomers', 35),
#  ('teodosic', 35),
#  ('drafted', 35),
#  ('friends', 35),
#  ('favorite', 35),
#  ('sosa', 35),
#  ('jersey', 34),
#  ('moved', 34),
#  ('worth', 34),
#  ('regular-season', 34),
#  ('lose', 34),
#  ('single', 34),
#  ('whats', 34),
#  ('sign', 34),
#  ('various', 34),
#  ('signed', 34),
#  ('passing', 34),
#  ('frank', 34),
#  ('hours', 34),
#  ('worse', 34),
#  ('multiple', 34),
#  ('mostly', 34),
#  ('talking', 34),
#  ('however', 34),
#  ('men', 34),
#  ('…', 34),
#  ('support', 34),
#  ('korver', 34),
#  ('goal', 34),
#  ('perry', 34),
#  ('operations', 33),
#  ('hands', 33),
#  ('outscored', 33),
#  ('possession', 33),
#  ('running', 33),
#  ('adding', 33),
#  ('certainly', 33),
#  ('antetokounmpo', 33),
#  ('enes', 33),
#  ('fell', 33),
#  ('couple', 33),
#  ('immediately', 33),
#  ('atlanta', 33),
#  ('outlook', 33),
#  ('al', 33),
#  ('attention', 33),
#  ('passes', 33),
#  ('mullin', 33),
#  ('nash', 33),
#  ('remains', 32),
#  ('mind', 32),
#  ('watched', 32),
#  ('hand', 32),
#  ('andre', 32),
#  ('capable', 32),
#  ('serious', 32),
#  ('acquired', 32),
#  ('rim', 32),
#  ('followed', 32),
#  ('result', 32),
#  ('report', 32),
#  ('surgery', 32),
#  ('thanks', 32),
#  ('hawks', 32),
#  ('opponents', 32),
#  ('works', 32),
#  ('none', 32),
#  ('eric', 32),
#  ('chief', 32),
#  ('needs', 32),
#  ('departures', 32),
#  ('32', 32),
#  ('nowitzki', 32),
#  ('row', 32),
#  ('healthy', 32),
#  ('happen', 32),
#  ('space', 32),
#  ('hornets', 32),
#  ('musselman', 32),
#  ('recalled', 31),
#  ('weekend', 31),
#  ('company', 31),
#  ('personal', 31),
#  ('defending', 31),
#  ('stuff', 31),
#  ('finish', 31),
#  ('isnt', 31),
#  ('happens', 31),
#  ('guards', 31),
#  ('kobe', 31),
#  ('culture', 31),
#  ('trouble', 31),
#  ('reach', 31),
#  ('commissioner', 31),
#  ('largely', 31),
#  ('31', 31),
#  ('parker', 31),
#  ('either', 31),
#  ('february', 31),
#  ('film', 31),
#  ('system', 31),
#  ('colangelo', 31),
#  ('reeve', 31),
#  ('decades', 30),
#  ('plan', 30),
#  ('stop', 30),
#  ('across', 30),
#  ('champions', 30),
#  ('blocks', 30),
#  ('talented', 30),
#  ('2018', 30),
#  ('previous', 30),
#  ('35', 30),
#  ('health', 30),
#  ('jump', 30),
#  ('perfect', 30),
#  ('turnovers', 30),
#  ('decided', 30),
#  ('definitely', 30),
#  ('inside', 30),
#  ('agent', 30),
#  ('brother', 30),
#  ('2013', 30),
#  ('struggled', 30),
#  ('continued', 30),
#  ('died', 30),
#  ('wrote', 30),
#  ('screen', 30),
#  ('goes', 30),
#  ('attempt', 30),
#  ('kansas', 30),
#  ('movement', 30),
#  ('officers', 30),
#  ('retired', 29),
#  ('join', 29),
#  ('beginning', 29),
#  ('deep', 29),
#  ('training', 29),
#  ('carmelo', 29),
#  ('exactly', 29),
#  ('changed', 29),
#  ('simply', 29),
#  ('leonard', 29),
#  ('difference', 29),
#  ('country', 29),
#  ('children', 29),
#  ('n.f.l', 29),
#  ('china', 29),
#  ('competitive', 29),
#  ('dolan', 29),
#  ('charles', 29),
#  ('champion', 29),
#  ('sabonis', 29),
#  ('fine', 29),
#  ('grizzlies', 29),
#  ('dan', 29),
#  ('noah', 29),
#  ('talked', 29),
#  ('matchup', 29),
#  ('accounts', 29),
#  ('gelfand', 29),
#  ('erving', 28),
#  ('yes', 28),
#  ('acknowledged', 28),
#  ('push', 28),
#  ('holiday', 28),
#  ('plenty', 28),
#  ('heard', 28),
#  ('entered', 28),
#  ('havent', 28),
#  ('van', 28),
#  ('younger', 28),
#  ('agency', 28),
#  ('100', 28),
#  ('must', 28),
#  ('currys', 28),
#  ('fall', 28),
#  ('ways', 28),
#  ('street', 28),
#  ('referring', 28),
#  ('considered', 28),
#  ('theyve', 28),
#  ('growing', 28),
#  ('seat', 28),
#  ('imagine', 28),
#  ('scheduled', 28),
#  ('pay', 28),
#  ('question', 28),
#  ('terry', 28),
#  ('moments', 28),
#  ('preseason', 28),
#  ('create', 28),
#  ('orlando', 28),
#  ('50', 28),
#  ('list', 28),
#  ('bulls', 28),
#  ('voice', 28),
#  ('casey', 28),
#  ('2012', 28),
#  ('toward', 28),
#  ('drive', 27),
#  ('g', 27),
#  ('ran', 27),
#  ('kids', 27),
#  ('41', 27),
#  ('takes', 27),
#  ('morris', 27),
#  ('leaving', 27),
#  ('meanwhile', 27),
#  ('lack', 27),
#  ('gundy', 27),
#  ('turns', 27),
#  ('charlotte', 27),
#  ('phil', 27),
#  ('throw', 27),
#  ('greatest', 27),
#  ('larry', 27),
#  ('runs', 27),
#  ('control', 27),
#  ('scorer', 27),
#  ('provided', 27),
#  ('understand', 27),
#  ('live', 27),
#  ('problem', 27),
#  ('jumpers', 27),
#  ...]

# %% [markdown]
# Restricting to nouns:

# %%
tags = corpus_blob.pos_tags

# %%
tags = [tag for tag in tags if tag[1] in {'NN','NNS','NNP','NNPS'}]

# %%
tags = [Word(tag[0].lower()) for tag in tags]

# %%
lemma_tags = [tag.lemmatize() for tag in tags]
lemma_tags = [tag for tag in tags if tag not in ['s','t']]

# %%
c2 = Counter(lemma_tags)
c2.most_common(20)
# Out:
# [('game', 1350),
#  ('points', 960),
#  ('team', 927),
#  ('season', 844),
#  ('n.b.a', 679),
#  ('james', 633),
#  ('players', 602),
#  ('knicks', 590),
#  ('warriors', 521),
#  ('games', 514),
#  ('coach', 499),
#  ('time', 454),
#  ('teams', 447),
#  ('basketball', 439),
#  ('league', 377),
#  ('cavaliers', 370),
#  ('player', 366),
#  ('night', 348),
#  ('years', 346),
#  ('celtics', 302)]

# %% [markdown]
# # 3. Prototype NER techniques:

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Note spacy restricts us to using a maximum of two thirds of the corpus:

# %%
doc = nlp(corpus[:999999])

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# Virginia 32 40 GPE
# Julius Erving 70 83 ORG
# the New York Nets 87 104 ORG
# 1973 108 112 DATE
# Erving 114 120 ORG
# first 132 137 ORDINAL
# Nassau Coliseum 149 164 ORG
#
#  254 255 GPE
# Erving 273 279 ORG
#
#  386 387 GPE
# Coliseum 391 399 ORG
# Erving 428 434 ORG
# Long Island 469 480 LOC
# Roosevelt High School 504 525 ORG
# three seasons 535 548 DATE
# two 634 637 CARDINAL
# A.B.A. 638 644 GPE
# the N.B.A. and Erving 689 710 ORG
# the Philadelphia 76ers 723 745 ORG
#
#  746 747 GPE
# Erving 751 757 ORG
# Long Island 782 793 LOC
# this weekend 857 869 DATE
# Coliseum 923 931 GPE
# first 940 945 ORDINAL
# decades 954 961 DATE
# J 972 973 PERSON
#
#  1008 1009 GPE
# The Long Island Nets 1009 1029 FAC
# the N.B.A. G League 1039 1058 ORG
# the Brooklyn Nets 1072 1089 ORG
# Erving 1105 1111 ORG
# Don Ryan 1138 1146 PERSON
# Saturdays season 1151 1167 DATE
# the Fort Wayne Mad Ants 1183 1206 ORG
# New York Nets 1220 1233 GPE
# Ryan 1262 1266 PERSON
#
#  1364 1365 GPE
# opening night 1375 1388 TIME
# Alton Byrd 1487 1497 PERSON
#
#  1559 1560 GPE
# Coliseum 1657 1665 PERSON
# last season 1681 1692 DATE
# first 1700 1705 ORDINAL
# Barclays Center 1710 1725 ORG
# Nets 1799 1803 FAC
# Barclays 1828 1836 PERSON
#
#  1892 1893 GPE
# Byrd 1910 1914 PERSON
# Julius 1952 1958 ORG
#
#  2021 2022 GPE
# 67 2030 2032 CARDINAL
# at least 10 days 2075 2091 DATE
# J Enterprises 2184 2197 PERSON
# Erving 2248 2254 ORG
# Saturdays 2268 2277 DATE
# Erving 2328 2334 ORG
# Barclays 2343 2351 ORG
# June 2355 2359 DATE
# three 2379 2384 CARDINAL
#
#  2508 2509 GPE
# Erving 2519 2525 ORG
# Ryan 2576 2580 PERSON
# Don 2672 2675 PERSON
#
#  2676 2677 GPE
# one 2731 2734 CARDINAL
# Erving 2772 2778 ORG
# last week 2801 2810 DATE
#
#  2811 2812 GPE
# Ryan 2812 2816 PERSON
# Long Island 2842 2853 LOC
# nearly 60 years 2858 2873 DATE
# last year 2894 2903 DATE
# the Village of Hempstead 2914 2938 GPE
#
#  2976 2977 GPE
# 1962 3005 3009 DATE
# Erving 3016 3022 ORG
# 12 years old 3027 3039 DATE
# Campbell Park 3088 3101 FAC
# Hempstead 3105 3114 GPE
# the Salvation Army 3168 3186 ORG
# Ryan 3194 3198 PERSON
# Ryan 3293 3297 PERSON
#
#  3312 3313 GPE
# Ryan 3338 3342 PERSON
# Erving 3356 3362 ORG
# the years 3376 3385 DATE
# ‘Hes 3529 3533 PRODUCT
# ‘Hes 3612 3616 PERSON
#
#  3642 3643 GPE
# Erving 3655 3661 ORG
# Long Island 3674 3685 LOC
# Ryan 3708 3712 PERSON
#
#  3789 3790 GPE
# Erving 3790 3796 ORG
# thirds 3821 3827 CARDINAL
# five years 3841 3851 DATE
# A.B.A. 3859 3865 GPE
# first 3867 3872 ORDINAL
# Squires 3882 3889 PERSON
# Nets 3903 3907 FAC
# three 4031 4036 CARDINAL
# five 4078 4082 CARDINAL
# 1983 4154 4158 DATE
# 1987 4174 4178 DATE
# A.B.A. 4192 4198 GPE
# N.B.A. 4203 4209 GPE
# All-Star 4210 4218 ORG
#
#  4219 4220 GPE
#   4355 4356 NORP
#   4393 4394 NORP
# one 4459 4462 CARDINAL
# just a few miles 4508 4524 QUANTITY
#
#  4589 4590 GPE
#
#  4772 4773 GPE
# Nets 4783 4787 FAC
# 28.2 4818 4822 CARDINAL
# 10.9 4834 4838 CARDINAL
# the A.B.A.s Most Valuable Player 4877 4909 ORG
# three 4925 4930 CARDINAL
#
#  4939 4940 GPE
# 1974 5021 5025 DATE
# California 5074 5084 GPE
# Columbia 5135 5143 GPE
# the PanAm Building 5194 5212 FAC
# the MetLife Building 5218 5238 FAC
#
#  5299 5300 GPE
# Js 5317 5319 PERSON
#
#  5381 5382 GPE
# Columbia 5382 5390 ORG
# Credit Erving 5490 5503 ORG
# one 5509 5512 CARDINAL
#
#  5521 5522 GPE
# one 5541 5544 CARDINAL
# four 5548 5552 CARDINAL
# A.B.A. 5553 5559 GPE
# 1976 5599 5603 DATE
# New Jersey 5614 5624 GPE
# 1977 5628 5632 DATE
# Erving 5634 5640 ORG
# 76ers 5685 5690 DATE
# this day 5699 5707 DATE
#
#  5821 5822 GPE
# New York Nets 5911 5924 GPE
# Erving 5953 5959 ORG
# A.B.A. 6033 6039 ORG
# the G League 6045 6057 ORG
# secondary 6076 6085 ORDINAL
#
#  6140 6141 GPE
# Erving 6205 6211 ORG
#
#  6217 6218 GPE
# Coliseum 6300 6308 GPE
#
#  6342 6343 GPE
# OAKLAND 6343 6350 GPE
# Calif. 6352 6358 GPE
# Kevin Durant 6360 6372 PERSON
# Draymond Green 6377 6391 ORG
# second 6412 6418 ORDINAL
# the Golden State Warriors 6477 6502 FAC
# Oracle Arena 6538 6550 PERSON
# this time of year 6581 6598 DATE
#
#  6599 6600 GPE
# Stephen Curry 6676 6689 PERSON
# Curry 6754 6759 ORG
# March 23 6844 6852 DATE
#
#  6853 6854 GPE
# 26 6865 6867 CARDINAL
# 13 6879 6881 CARDINAL
# Green 6892 6897 ORG
# fourth 6934 6940 ORDINAL
# the New Orleans Pelicans 7012 7036 FAC
# 123 7043 7046 CARDINAL
# Game 1 7058 7064 EVENT
# Western Conference 7074 7092 PRODUCT
# Saturday 7104 7112 DATE
# night 7113 7118 TIME
# 16 7140 7142 CARDINAL
# 15 7151 7153 CARDINAL
# 11 7164 7166 CARDINAL
# three 7176 7181 CARDINAL
# two 7193 7196 CARDINAL
# second 7309 7315 ORDINAL
#
#  7324 7325 GPE
# Green 7457 7462 ORG
#
#  7468 7469 GPE
# Anthony Davis 7482 7495 PERSON
# 21 7500 7502 CARDINAL
# 10 7514 7516 CARDINAL
# 10 7535 7537 CARDINAL
# the first quarter 7541 7558 DATE
# 9 7635 7636 CARDINAL
# 20 7641 7643 CARDINAL
# Jrue Holiday 7645 7657 PERSON
# 4-for-14 7670 7678 CARDINAL
# 11 7692 7694 CARDINAL
#
#  7702 7703 GPE
# Curry 7730 7735 ORG
# two 7741 7744 CARDINAL
# Game 2 7788 7794 EVENT
# Tuesday night 7798 7811 TIME
#
#  7872 7873 GPE
# Curry 7873 7878 ORG
# Thursday 7921 7929 DATE
# 5 7950 7951 CARDINAL
# 5 7955 7956 CARDINAL
# first 7965 7970 ORDINAL
# Friday 7976 7982 DATE
# Steve Kerr 7994 8004 PERSON
# Curry 8018 8023 ORG
# Sunday 8067 8073 DATE
#
#  8074 8075 GPE
# Tuesday 8134 8141 DATE
# Klay Thompson 8199 8212 PERSON
# Steph 8480 8485 PERSON
# the day 8494 8501 DATE
#
#  8584 8585 GPE
# Thompson 8585 8593 ORG
# Golden State 8603 8615 ORG
# 27 8621 8623 CARDINAL
# 3-pointers 8649 8659 CARDINAL
# late in 8660 8667 TIME
# the first half 8668 8682 DATE
# 76-48 8696 8701 CARDINAL
# New Orleans 8707 8718 GPE
# second 8729 8735 ORDINAL
# 7 8741 8742 CARDINAL
# Darius Millers 8754 8768 ORG
# Pelicans 8827 8835 NORP
# 76-55 8843 8848 DATE
# third 8905 8910 ORDINAL
#
#  8944 8945 GPE
# Rajon Rondo 8945 8956 PERSON
# nine 8961 8965 CARDINAL
# 11 8988 8990 CARDINAL
# New Orleans 9003 9014 GPE
#
#  9015 9016 GPE
# Pelicans Coach 9048 9062 PERSON
# Alvin Gentry 9063 9075 PERSON
#
#  9081 9082 GPE
# Pelicans 9160 9168 NORP
#
#  9187 9188 GPE
# all year 9233 9241 DATE
# Steve Kerr 9249 9259 PERSON
#
#  9265 9266 GPE
# Davis 9266 9271 PERSON
# 33 9286 9288 CARDINAL
# 12 9297 9299 CARDINAL
# 2.8 9313 9316 CARDINAL
# first 9329 9334 ORDINAL
# Portland 9350 9358 GPE
# 5 9365 9366 CARDINAL
# 7 9370 9371 CARDINAL
# weeklong 9403 9411 DATE
# Gentry 9425 9431 ORG
#
#  9437 9438 GPE
# Golden State 9480 9492 ORG
# 26 9559 9561 CARDINAL
# 4 9602 9603 CARDINAL
# 19 9641 9643 CARDINAL
# 18 9648 9650 CARDINAL
# two 9673 9676 CARDINAL
# five 9691 9695 CARDINAL
# San Antonio 9713 9724 GPE
# first 9732 9737 ORDINAL
#
#  9744 9745 GPE
# Gentry 9842 9848 ORG
#
#  9854 9855 GPE
# Nick Young 9855 9865 PERSON
# Andre Iguodala 9908 9922 PERSON
# Curry as Golden State 9967 9988 ORG
# 13th 10012 10016 ORDINAL
#
#  10047 10048 GPE
# Pelicans 10071 10079 NORP
# 2015 10145 10149 DATE
# first 10150 10155 ORDINAL
# Golden State 10165 10177 ORG
# first 10201 10206 ORDINAL
# 40 years 10223 10231 DATE
#
#  10232 10233 GPE
# Golden State 10233 10245 ORG
# first 10286 10291 ORDINAL
# half 10292 10296 CARDINAL
# 76 10328 10330 CARDINAL
# 73 10345 10347 CARDINAL
# Phoenix 10356 10363 GPE
# May 4, 1994 10367 10378 DATE
# 41 10386 10388 CARDINAL
# second 10396 10402 ORDINAL
# 40 10414 10416 CARDINAL
# Utah 10432 10436 GPE
# May 11, 2007 10440 10452 DATE
#
#  10453 10454 GPE
# Golden State 10454 10466 ORG
# 13 10472 10474 CARDINAL
# 20 10479 10481 CARDINAL
# second 10489 10495 ORDINAL
# four 10504 10508 CARDINAL
# 3s 10509 10511 PRODUCT
# 11 10516 10518 CARDINAL
# 14 10522 10524 CARDINAL
#
#  10537 10538 GPE
# The Golden State Warriors 10538 10563 FAC
# the regular season 10690 10708 DATE
#
#  10709 10710 GPE
# Kevin Durant 10710 10722 PERSON
# 24 10795 10797 CARDINAL
# 8 10806 10807 CARDINAL
# 7 10821 10822 CARDINAL
# San Antonio Spurs 10929 10946 LOC
# 113 10948 10951 CARDINAL
# Saturday 10959 10967 DATE
# Oakland 10971 10978 GPE
# Calif. 10980 10986 GPE
# Klay Thompson 10999 11012 PERSON
# Game 1 11062 11068 PRODUCT
# the season 11085 11095 DATE
#
#  11277 11278 GPE
#
#  11356 11357 GPE
# Thompson 11365 11373 ORG
# Draymond Green 11378 11392 ORG
# Game 1 11408 11414 EVENT
# first 11422 11427 ORDINAL
# All-Star 11512 11520 ORG
# two 11533 11536 CARDINAL
# Stephen Curry 11563 11576 PERSON
# March 23 11607 11615 DATE
# Thompson 11643 11651 ORG
# 27 11688 11690 CARDINAL
# 11 11706 11708 CARDINAL
# 13 11712 11714 CARDINAL
# JaVale McGee 11741 11753 ORG
# Steve Kerrs 11765 11776 PERSON
# 15 11822 11824 CARDINAL
# 4 11833 11834 CARDINAL
# 2 11848 11849 CARDINAL
# 16 minutes 11860 11870 TIME
# 12 11890 11892 CARDINAL
# 11 11901 11903 CARDINAL
# 8 11916 11917 CARDINAL
#
#  11927 11928 GPE
# Rudy Gay 11928 11936 PERSON
# Spurs 11945 11950 PERSON
# 15 11956 11958 CARDINAL
# LaMarcus Aldridge 11981 11998 PERSON
# 14 12014 12016 CARDINAL
# 5-for-12 12027 12035 CARDINAL
#
#  12045 12046 GPE
# The first quarter 12046 12063 DATE
# Spurs 12103 12108 PERSON
# Gregg Popovich 12115 12129 PERSON
# Game 2 12136 12142 LAW
# seven 12158 12163 CARDINAL
# Monday 12174 12180 DATE
# night 12181 12186 TIME
# Oracle Arena 12195 12207 PERSON
#
#  12208 12209 GPE
# Curry 12286 12291 ORG
#
#  12292 12293 GPE
# Golden State 12293 12305 ORG
# all week 12311 12319 DATE
# a new season 12332 12344 DATE
#
#  12435 12436 GPE
# Green 12467 12472 ORG
# this time a year 12501 12517 DATE
#
#  12525 12526 GPE
#
#  12619 12620 GPE
# Golden State 12620 12632 ORG
#
#  12797 12798 GPE
# San Antonio 12798 12809 GPE
#
#  12847 12848 GPE
# San Antonios 12895 12907 GPE
# Danny Green 12908 12919 PERSON
#
#  13061 13062 GPE
# four 13086 13090 CARDINAL
# All-Stars 13091 13100 PRODUCT
# Golden State 13111 13123 ORG
# last month 13142 13152 DATE
# seven 13170 13175 CARDINAL
# 10 13179 13181 CARDINAL
#
#  13182 13183 GPE
# Golden State 13183 13195 ORG
# San Antonio 13202 13213 GPE
# the Western Conference 13217 13239 LOC
# a year ago 13247 13257 DATE
# second 13274 13280 ORDINAL
# three 13297 13302 CARDINAL
# 16-1 13346 13350 CARDINAL
# Kerr 13367 13371 PERSON
#
#  13440 13441 GPE
#
#  13519 13520 GPE
# Durant 13527 13533 GPE
#
#  13608 13609 GPE
# M.V.P. 13613 13619 GPE
# 2015 13627 13631 DATE
# Andre Iguodala 13640 13654 PERSON
# 2018 13695 13699 DATE
#
#  13821 13822 GPE
# Iguodala 13822 13830 GPE
# seven 13849 13854 CARDINAL
# Saturday 13879 13887 DATE
# four 13900 13904 CARDINAL
# five 13918 13922 CARDINAL
# Kerr 13967 13971 PERSON
#
#  14006 14007 GPE
# one 14063 14066 CARDINAL
# Kerr 14096 14100 PERSON
# years 14209 14214 DATE
#
#  14215 14216 GPE
# Ben Simmons 14216 14227 PERSON
# 17 14232 14234 CARDINAL
# 14 14243 14245 CARDINAL
# 9 14258 14259 CARDINAL
# Philadelphia 14295 14307 GPE
# Joel Embiid 14329 14340 PERSON
# Miami 14359 14364 GPE
# 17th 14371 14375 DATE
#
#  14393 14394 GPE
# Embiid 14394 14400 NORP
# Game 1 14449 14455 EVENT
# first 14463 14468 ORDINAL
# Eastern Conference series 14475 14500 EVENT
# Embiid 14656 14662 NORP
# Heat 14731 14735 ORG
# Marco Belinelli 14774 14789 PERSON
# Ersan Ilyasova 14794 14808 ORG
# Belinelli 14810 14819 PERSON
# Ilyasova 14824 14832 GPE
# four 14849 14853 CARDINAL
# 3-pointers 14854 14864 CARDINAL
# the third quarter 14868 14885 DATE
# 15 15019 15021 CARDINAL
# the third quarter 15031 15048 DATE
# first 15082 15087 ORDINAL
# five seasons 15107 15119 DATE
# Brett Brown 15132 15143 PERSON
#
#  15144 15145 GPE
# Brown 15145 15150 PERSON
# 47 15155 15157 CARDINAL
# first 15168 15173 ORDINAL
# three 15174 15179 CARDINAL
# Process 15216 15223 PRODUCT
# 52 15229 15231 CARDINAL
# Game 1 15238 15244 EVENT
# this season 15246 15257 DATE
#
#  15258 15259 GPE
# Brown 15306 15311 PERSON
# J Redick 15320 15328 PERSON
# 28 15336 15338 CARDINAL
# Game 2 15380 15386 EVENT
# Monday 15390 15396 DATE
# Belinelli 15398 15407 PERSON
# 25 15412 15414 CARDINAL
# 17 15428 15430 CARDINAL
#
#  15431 15432 GPE
# half 15438 15442 CARDINAL
# one 15482 15485 CARDINAL
# James Johnson 15521 15534 PERSON
# Kelly Olynyk 15539 15551 PERSON
# 60-56 15571 15576 CARDINAL
# 26 15621 15623 CARDINAL
#
#  15631 15632 GPE
# Heat 15640 15644 EVENT
# 26 percent 15650 15660 PERCENT
# third 15668 15673 ORDINAL
# 34-18 15694 15699 CARDINAL
# Ilyasovas 3-pointer 15721 15740 PRODUCT
# 66 15769 15771 CARDINAL
# Philadelphia 15775 15787 GPE
# Dario Saric 15794 15805 PERSON
# two years 15834 15843 DATE
# 3 15884 15885 CARDINAL
# Olynyk 15944 15950 GPE
# two 15995 15998 CARDINAL
#
#  16011 16012 GPE
# 114 16020 16023 CARDINAL
# Wizards 106 16025 16036 ORG
# 23 16053 16055 CARDINAL
# 12 16067 16069 CARDINAL
# Delon Wright 16080 16092 PERSON
# 11 16100 16102 CARDINAL
# 18 16110 16112 CARDINAL
# the fourth quarter 16123 16141 DATE
# Toronto 16152 16159 GPE
# 10 16178 16180 CARDINAL
# Eastern Conference 16227 16245 LOC
# Washington 16252 16262 GPE
#
#  16263 16264 GPE
# DeMar DeRozan 16264 16277 PERSON
# 17 16284 16286 CARDINAL
# C. J. Miles 16295 16306 PERSON
# G Anunoby 16313 16322 ORG
# 12 16332 16334 CARDINAL
# Kyle Lowry 16340 16350 ORG
# 11 16355 16357 CARDINAL
# 9 16369 16370 CARDINAL
# second 16476 16482 ORDINAL
# Philadelphia 16497 16509 GPE
# 2001 16513 16517 DATE
#
#  16518 16519 GPE
# Toronto 16519 16526 GPE
# N.B.A 16550 16555 GPE
# 10 16563 16565 CARDINAL
# Game 16578 16582 FAC
# six 16608 16611 CARDINAL
#
#  16620 16621 GPE
# DeRozan 16645 16652 PERSON
# Worry about Game 2. 16673 16692 ORG
#
#  16692 16693 GPE
# the Eastern Conference 16716 16738 LOC
# Toronto 16740 16747 GPE
# 16 16753 16755 CARDINAL
# 30 3-point 16759 16769 CARDINAL
# Miles 16785 16790 GPE
# four 16798 16802 CARDINAL
# Ibaka 16807 16812 GPE
# Wright 16817 16823 PERSON
# three 16837 16842 CARDINAL
#
#  16843 16844 GPE
# Game 2 16866 16872 EVENT
# Tuesday 16876 16883 DATE
#
#  16884 16885 GPE
# John Wall 16885 16894 PERSON
# 23 16899 16901 CARDINAL
# 15 16913 16915 CARDINAL
# Wizards 16932 16939 ORG
# Markieff Morris 16947 16962 PERSON
# 22 16967 16969 CARDINAL
# 11 16981 16983 CARDINAL
#
#  16993 16994 GPE
# Bradley Beal 16994 17006 ORG
# 19 17014 17016 CARDINAL
# Washington 17028 17038 GPE
# Mike Scott 17046 17056 PERSON
# 14 17061 17063 DATE
# Marcin Gortat 17068 17081 PERSON
# 12 17089 17091 CARDINAL
#
#  17092 17093 GPE
# Washington 17093 17103 GPE
# 91-88 17117 17122 DATE
# Scott 17129 17134 ORG
# Lowry 17197 17202 ORG
# early in the fourth quarter 17208 17235 TIME
# Lowry 17237 17242 ORG
# Wright 17297 17303 PERSON
# Toronto 17309 17316 GPE
# Morris 17363 17369 PERSON
# Miles 17371 17376 PERSON
# 3-pointer 17383 17392 CARDINAL
# 7 17404 17405 CARDINAL
# 95 17436 17438 CARDINAL
# 9 minutes 26 seconds 17452 17472 TIME
#
#  17478 17479 GPE
# Kelly Oubre Jr. 17479 17494 PERSON
# Gortat 17508 17514 PERSON
# Washington 17536 17546 GPE
# Wright 17566 17572 PERSON
# Miles 17577 17582 PERSON
# 3-pointers 17592 17602 CARDINAL
# Toronto 17606 17613 GPE
# 8 17622 17623 CARDINAL
# 103 17640 17643 CARDINAL
# 6:27 17657 17661 CARDINAL
#
#  17691 17692 GPE
# Anthony Davis 17692 17705 PERSON
# 35 17710 17712 CARDINAL
# 14 17721 17723 CARDINAL
# four 17737 17741 CARDINAL
# New Orleans 17758 17769 NORP
# Pelicans 17770 17778 NORP
# the Portland Trail Blazers 17784 17810 ORG
# 97-95 17812 17817 CARDINAL
# Game 1 17822 17828 LAW
#
#  17853 17854 GPE
# Jrue Holiday 17854 17866 PERSON
# 21 17873 17875 CARDINAL
# Damian Lillard 17900 17914 PERSON
# C.J. McCollum 17919 17932 PERSON
# the closing seconds 17964 17983 TIME
# New Orleans 17987 17998 GPE
# Portland 18013 18021 GPE
# 19-point 18045 18053 CARDINAL
#
#  18062 18063 GPE
# Rajon Rondo 18063 18074 PERSON
# 17 18089 18091 CARDINAL
# eight 18101 18106 CARDINAL
# LeBron James 28554 28566 PERSON
# Michael Jordan 28574 28588 PERSON
# 100 28638 28641 CARDINAL
# James 28658 28663 PERSON
# 28 28678 28680 CARDINAL
# 12 28692 28694 CARDINAL
# Cleveland 28738 28747 GPE
# first 28768 28773 ORDINAL
# this season 28779 28790 DATE
# the third quarter 28816 28833 DATE
#
#  28834 28835 GPE
# Last years 28835 28845 DATE
# 17 28891 28893 CARDINAL
# Thaddeus Young 28945 28959 PERSON
# all year 29001 29009 DATE
#
#  29035 29036 GPE
#
#  29084 29085 GPE
# Pacers 29095 29101 PERSON
# Bogdanovic 29148 29158 PERSON
# 4-point 29171 29178 CARDINAL
# Pacers 29198 29204 PERSON
# 81-77 29208 29213 CARDINAL
# 6 minutes 10 seconds 29224 29244 TIME
# 3-pointer 29283 29292 CARDINAL
# 7-point 29308 29315 CARDINAL
#
#  29321 29322 GPE
# James 29322 29327 PERSON
# 7 29351 29352 CARDINAL
#
#  29377 29378 GPE
# Young 29445 29450 PERSON
# Pacers 29477 29483 PERSON
# 91-84 29486 29491 CARDINAL
# 53 seconds 29505 29515 TIME
#
#  29521 29522 GPE
# James 29522 29527 PERSON
# 3-pointer 29543 29552 CARDINAL
# 4 29577 29578 CARDINAL
# Cavs 29588 29592 ORG
# 3 29605 29606 CARDINAL
# Kevin Love 29612 29622 PERSON
# seven seconds 29628 29641 TIME
# 91-90 29658 29663 CARDINAL
#
#  29664 29665 GPE
# Darren Collison 29665 29680 PERSON
# five seconds 29704 29716 TIME
# Cleveland 29730 29739 GPE
# J. R. Smiths 29761 29773 PERSON
#
#  29811 29812 GPE
# James 29855 29860 PERSON
# the second half 29927 29942 DATE
#
#  29973 29974 GPE
# WIZARDS 122 29974 29985 FAC
# 103 29995 29998 CARDINAL
# 21 30060 30062 CARDINAL
# 28 30070 30072 CARDINAL
# the first half 30083 30097 DATE
# John Wall 30135 30144 PERSON
# 28 30155 30157 CARDINAL
# 14 30169 30171 CARDINAL
# Washington 30185 30195 GPE
# Toronto 30210 30217 GPE
# first 30277 30282 ORDINAL
# Eastern Conference series 30289 30314 EVENT
# two 30318 30321 CARDINAL
# one 30331 30334 CARDINAL
#
#  30335 30336 GPE
# first 30371 30376 ORDINAL
# two 30377 30380 CARDINAL
# Wizards 30433 30440 ORG
# Scott Brooks 30487 30499 PERSON
# only three 30535 30545 CARDINAL
# Game 2 30555 30561 PRODUCT
# the first quarter 30593 30610 DATE
# 30-29 30612 30617 CARDINAL
# 19 30670 30672 CARDINAL
# Toronto 30673 30680 GPE
# 28 30703 30705 CARDINAL
# Washington 30706 30716 GPE
#
#  30724 30725 GPE
# Washington 30758 30768 GPE
# seven 30785 30790 CARDINAL
# eight 30794 30799 CARDINAL
# the regular season 30820 30838 DATE
#
#  30839 30840 GPE
# DeMar DeRozan 30840 30853 PERSON
# Toronto 30858 30865 GPE
# 23 30871 30873 CARDINAL
# 10-for-22 30884 30893 CARDINAL
# 37 30925 30927 CARDINAL
# Kyle Lowry 30933 30943 ORG
# 19 30948 30950 CARDINAL
# 8 assists 30962 30971 QUANTITY
# 116 30979 30982 CARDINAL
# CELTICS 30984 30991 ORG
# 92 30992 30994 CARDINAL
# Khris Middleton 30995 31010 ORG
# 23 31018 31020 CARDINAL
# Milwaukee 31042 31051 GPE
# Boston 31057 31063 GPE
# two 31093 31096 CARDINAL
# one 31106 31109 CARDINAL
# NYT)
#  31112 31117 ORG
# WINSLOW 31117 31124 ORG
# Miamis 31148 31154 NORP
# Justise Winslow 31155 31170 PERSON
# 15,000 31172 31178 MONEY
# Philadelphia 31232 31244 GPE
# Joel Embiids 31252 31264 GPE
# Thursday 31273 31281 DATE
# Winslow 31283 31290 PERSON
# Embiids 31316 31323 NORP
# AP 31366 31368 ORG
#
#  31369 31370 GPE
# Michael Jordan 31413 31427 PERSON
# LeBron James 31489 31501 PERSON
# 6 31528 31529 CARDINAL
# 3 31532 31533 CARDINAL
#
#  31534 31535 GPE
# 6 31589 31590 CARDINAL
# 3 31593 31594 CARDINAL
# Jordans 31637 31644 NORP
# 6 31645 31646 CARDINAL
# Jamess 31677 31683 ORG
# 3-5 31684 31687 PERCENT
# Jerry West   31825 31837 PERSON
# 1 31845 31846 CARDINAL
#
#  31897 31898 GPE
# first 32014 32019 ORDINAL
# Saturday 32045 32053 DATE
#
#  32216 32217 GPE
# Stephen Curry 32220 32233 PERSON
# the Golden State Warriors 32238 32263 GPE
# the last three years 32392 32412 DATE
# fourth 32427 32433 ORDINAL
# James 32448 32453 PERSON
# Chris Paul 32486 32496 PERSON
# the Houston Rockets 32500 32519 LOC
# his 13th year 32556 32569 DATE
#
#  32585 32586 GPE
# Kevin McHale 32586 32598 PERSON
# Hall of Famer 32602 32615 ORG
# Larry Bird 32632 32642 PERSON
# Robert Parish 32647 32660 PERSON
# the Boston Celtics 32664 32682 ORG
# three 32687 32692 CARDINAL
#
#  32900 32901 GPE
# 2 32997 32998 CARDINAL
# 2 minutes 33005 33014 TIME
#
#  33175 33176 GPE
# Kobe Bryant 33176 33187 FAC
# five 33251 33255 CARDINAL
# the Los Angeles Lakers 33275 33297 ORG
# ESPN+ 33343 33348 ORG
# Detail 33368 33374 LAW
#
#  33493 33494 GPE
#
#  33744 33745 GPE
# Bryant 33745 33751 ORG
#
#  34092 34093 GPE
# McHale 34093 34099 ORG
# TNT 34133 34136 ORG
# Jordan 34204 34210 GPE
# LeBron 34215 34221 PERSON
# Bill Russells 34242 34255 PERSON
# 11 34256 34258 CARDINAL
# Kareem Abdul-Jabbars 34278 34298 PERSON
#
#  34569 34570 GPE
# McHales 34570 34577 ORG
# Curry 34615 34620 ORG
# James 34625 34630 PERSON
# the coming months 34634 34651 DATE
# Russell 34759 34766 PERSON
# Jordan 34768 34774 GPE
# Abdul-Jabbar 34779 34791 GPE
# 6 34829 34830 CARDINAL
# 3 34833 34834 CARDINAL
# 1 35033 35034 CARDINAL
# Sunday 35036 35042 DATE
# 9 p.m. 35044 35050 TIME
# TNT
# Season 35052 35062 EVENT
# Rockets 35077 35084 ORG
# 4 35089 35090 CARDINAL
# Timberwolves 35117 35129 PRODUCT
# Utahs 38357 38362 ORG
# Donovan Mitchell 38363 38379 PERSON
# Philadelphias Ben Simmons 38384 38409 PERSON
# the year 38440 38448 DATE
# Jazz 38495 38499 ORG
# 48-34 38501 38506 DATE
#
#  38519 38520 GPE
# Utah 38520 38524 GPE
# Gordon Hayward 38530 38544 GPE
# Rudy Gobert 38616 38627 PERSON
# N.B.A. 38692 38698 GPE
# Mitchell 38700 38708 PERSON
# Ricky Rubio 38742 38753 PERSON
# Minnesotas 38777 38787 ORG
#
#  38858 38859 GPE
# 48-34 38872 38877 DATE
# Paul George 38918 38929 PERSON
# Carmelo Anthony 38934 38949 PERSON
# Russell Westbrook 38960 38977 PERSON
# Steven Adams 38982 38994 PERSON
# Oklahoma City 39000 39013 GPE
# Anthony 39043 39050 PERSON
# George 39167 39173 PERSON
# 1 39215 39216 CARDINAL
# Saturday 39218 39226 DATE
# 5:30 p.m. 39228 39237 TIME
# ESPN
#  39239 39244 ORG
# Season head-to-head 39244 39263 PERSON
# 2-2
# Winning 39271 39282 LAW
# first 39287 39292 ORDINAL
# 59-23 39343 39348 CARDINAL
# second-half 39379 39390 DATE
# East 39481 39485 LOC
# Game 1 39533 39539 LAW
# the Eastern Conference 39566 39588 ORG
# 2001 39603 39607 DATE
#
#  39705 39706 GPE
# Wizards 39710 39717 ORG
# 43 39719 39721 CARDINAL
# John Wall 39843 39852 PERSON
# all season 39956 39966 DATE
# Torontos 39977 39985 PERSON
# DeMar DeRozan 39994 40007 PERSON
# Kyle Lowry 40009 40019 ORG
# Jonas Valanciunas 40024 40041 PERSON
# Fred VanVleet 40073 40086 PERSON
# Jakob Poeltl 40126 40138 PERSON
# 1 40206 40207 CARDINAL
# Sunday 40209 40215 DATE
# 1 p.m. 40217 40223 TIME
# 2-2
# Injuries 40255 40267 CARDINAL
# Celtics 40295 40302 ORG
# 55-27 40304 40309 DATE
# Gordon Hayward 40335 40349 PERSON
# just minutes 40350 40362 TIME
# first 40372 40377 ORDINAL
# the regular season 40386 40404 DATE
# the Eastern Conference 40437 40459 ORG
#   40481 40482 NORP
# Kyrie Irving 40495 40507 PERSON
#
#  40605 40606 GPE
# Boston 40606 40612 GPE
# Jaylen Brown 40664 40676 PERSON
# Jayson Tatum 40681 40693 PERSON
# Celtics 40732 40739 ORG
# Hayward 40758 40765 LOC
# Irving 40770 40776 GPE
#
#  40826 40827 GPE
# 44-38 40838 40843 DATE
# the breakout season 40858 40877 DATE
# Giannis Antetokounmpo 40920 40941 PERSON
# first 41001 41006 ORDINAL
# 1 41108 41109 CARDINAL
# Saturday 41111 41119 DATE
# 8 p.m. 41121 41127 TIME
# ESPN
#  41129 41134 ORG
# Season head-to-head 41134 41153 PERSON
# 2 41160 41161 CARDINAL
# 76ers 41430 41435 DATE
# 52-30 41437 41442 CARDINAL
# the Eastern Conference 41481 41503 ORG
# Ben Simmons 41515 41526 PERSON
# one 41528 41531 CARDINAL
# two 41535 41538 CARDINAL
# the year 41563 41571 DATE
# the Fresh Prince 41595 41611 PERSON
# LeBron Jamess 41615 41628 PRODUCT
# Manhattan 49523 49532 GPE
# Cleveland Cavaliers 49550 49569 ORG
# Knicks 49603 49609 ORG
# 43-point fourth quarter 49623 49646 DATE
# 104 49663 49666 CARDINAL
#
#  49693 49694 GPE
# Knicks 49747 49753 ORG
# Ramsey 49761 49767 PERSON
# 23-point 49816 49824 CARDINAL
# the third quarter 49833 49850 DATE
# James 49906 49911 PERSON
# 3-pointer 49988 49997 CARDINAL
# Kristaps Porzingis 50016 50034 PERSON
#
#  50064 50065 GPE
# Jamess 50065 50071 PRODUCT
# Porzingis 50096 50105 GPE
# the fourth quarter 50109 50127 DATE
# early season 50181 50193 DATE
# Knicks 50249 50255 ORG
#
#  50283 50284 GPE
# Jamess night 50284 50296 TIME
# one 50310 50313 CARDINAL
# Ramseys 50383 50390 PERSON
# 80 50396 50398 DATE
# one 50416 50419 CARDINAL
# Gardens 50516 50523 LOC
#
#  50546 50547 GPE
# LeBron 50547 50553 ORG
# Michael Jordan 50577 50591 PERSON
# Kobe Bryant 50593 50604 ORG
# LeBron 50654 50660 PERSON
#
#  50728 50729 GPE
# Selma 50737 50742 GPE
# Ala. 50744 50748 GPE
# 1937 50753 50757 DATE
# New York 50782 50790 GPE
# Harlems Rucker Park 50812 50831 LOC
# Ramsey 50833 50839 PERSON
# Martin Luther King Jr.s 50921 50944 PERSON
# Washington 50964 50974 GPE
# Wilt Chamberlain 50980 50996 PERSON
# 1963 51000 51004 DATE
# Willis Reed 51028 51039 PERSON
# Knicks 51051 51057 ORG
# the early 1970s 51072 51087 DATE
#
#  51157 51158 GPE
# the fall of 1959 51179 51195 DATE
# Ramsey 51197 51203 PERSON
# Knicks 51219 51225 ORG
# New York University 51263 51282 ORG
# 11.4 51294 51298 CARDINAL
# 6.7 51310 51313 CARDINAL
# 22.9 minutes 51326 51338 TIME
# seven 51367 51372 CARDINAL
#  51428 51429 GPE
# Fuzzy Levane 51465 51477 PERSON
# Ned Irish 51533 51542 PERSON
# four 51563 51567 CARDINAL
# African 51568 51575 NORP
# one 51619 51622 CARDINAL
# Ray Felix 51633 51642 PERSON
# Johnny Green 51644 51656 PERSON
# Willie Naulls 51661 51674 PERSON
# Ramsey 51683 51689 PERSON
# Syracuse 51702 51710 GPE
#
#  51815 51816 GPE
# Monday 51828 51834 DATE
# night 51835 51840 TIME
# Carmelo Anthony 51858 51873 PERSON
# Knicks 51878 51884 ORG
# 29-13 second-quarter 51897 51917 TIME
# Latvian 51932 51939 NORP
# Porzingis 51947 51956 GPE
# France 51985 51991 GPE
# Frank Ntilikina 51993 52008 PERSON
# Turkish 52016 52023 NORP
#
#  52045 52046 GPE
# Ramsey 52087 52093 PERSON
# his day 52147 52154 DATE
# Knicks 52222 52228 ORG
# New York 52257 52265 GPE
#
#  52334 52335 GPE
# Anthony 52342 52349 PERSON
# Knicks 52359 52365 ORG
# James 52390 52395 PERSON
#   52427 52428 NORP
#   52446 52447 NORP
# Monday 52512 52518 DATE
# Jamess 52544 52550 ORG
# Knicks 52577 52583 ORG
# Ntilikina 52597 52606 GPE
# Dallass 52612 52619 ORG
# Miguel Ángel Mancera 56986 57006 PERSON
# English 57056 57063 LANGUAGE
# 25th 57117 57121 ORDINAL
# Mancera 57148 57155 ORG
# Mexico City 57172 57183 GPE
#
#  57229 57230 GPE
# Now 57230 57233 DATE
# Mancera 57235 57242 ORG
#
#  57304 57305 GPE
# Mancera 57340 57347 PERSON
# Adam Silver 57375 57386 PERSON
# recent months 57429 57442 DATE
#
#  57541 57542 GPE
#
#  57615 57616 GPE
# Mexican 57755 57762 NORP
# first 57838 57843 ORDINAL
# Mexico 57880 57886 GPE
# G League 57959 57967 ORG
# as early as next season 58010 58033 DATE
#
#  58034 58035 GPE
# Mexico 58096 58102 GPE
# Mexico City 58108 58119 GPE
#   58133 58134 NORP
# the United States 58207 58224 GPE
# 20 million 58271 58281 CARDINAL
#
#  58415 58416 GPE
# Mexico City 58430 58441 GPE
# the United States 58486 58503 GPE
# roughly 35 million 58521 58539 CARDINAL
# Mexican 58550 58557 NORP
# nearly 57 million 58570 58587 CARDINAL
# Latinos 58588 58595 ORG
#
#  58596 58597 GPE
# Mexico City 58654 58665 GPE
# United States 58707 58720 GPE
# Canada 58780 58786 GPE
# 1994 58811 58815 DATE
#
#  58816 58817 GPE
# Mexico City 58858 58869 GPE
# five-day 58901 58909 DATE
# about $20 to $450 58942 58959 MONEY
# two 58986 58989 CARDINAL
# 20,562 59018 59024 CARDINAL
# first 59032 59037 ORDINAL
# 19,777 59047 59053 CARDINAL
# second 59061 59067 ORDINAL
# the same week 59076 59089 DATE
# Liga MX 59186 59193 PRODUCT
# Clasico Regio 59202 59215 ORG
# Tigres 59230 59236 PERSON
# Monterrey 59257 59266 GPE
#
#  59267 59268 GPE
# Miami Heat 59362 59372 PERSON
# Kelly Olynyk 59381 59393 PERSON
# two 59410 59413 CARDINAL
# Mexico City 59445 59456 GPE
# Nets 59480 59484 GPE
# last week 59485 59494 DATE
#
#  59495 59496 GPE
# Mexico City 59577 59588 GPE
# Seattle 59745 59752 GPE
# first 59782 59787 ORDINAL
# SuperSonics 59843 59854 ORG
# Oklahoma City 59858 59871 GPE
# 2008 59875 59879 DATE
#
#  59880 59881 GPE
# Mexico 59922 59928 GPE
# Mexican 60114 60121 NORP
# Liga MX 60145 60152 PRODUCT
# One 60154 60157 CARDINAL
#
#  60286 60287 GPE
# one-weekend 60307 60318 DATE
# Gilberto Hernández 60336 60354 PERSON
# the Mexican Basketball Federation 60373 60406 ORG
#
#  60501 60502 GPE
# American 60561 60569 NORP
# daily 60754 60759 DATE
# Mexico 60769 60775 GPE
# Mexico 60860 60866 GPE
#
#  60878 60879 GPE
# $300 million 60883 60895 MONEY
# Azcapotzalco 60936 60948 ORG
# one 60950 60953 CARDINAL
# Mexico 60957 60963 GPE
# 16 60970 60972 CARDINAL
# six-year-old 61071 61083 DATE
# N.B.A 61111 61116 GPE
#
#  61445 61446 GPE
# three 61450 61455 CARDINAL
# Brooklyn 61463 61471 GPE
# Oklahoma City 61473 61486 GPE
# Miami 61491 61496 GPE
# last week 61510 61519 DATE
# Polanco 61547 61554 ORG
# one 61556 61559 CARDINAL
#
#  61831 61832 GPE
# the week 61846 61854 DATE
# The American School 61868 61887 ORG
# less than 10 miles 61888 61906 QUANTITY
# Polanco 61917 61924 ORG
#
#  62103 62104 GPE
# Horacio de la Vega Flores 62158 62183 PERSON
# Mexico 62202 62208 GPE
# two Olympic Games 62237 62254 EVENT
# Mexico 62293 62299 GPE
#
#  62472 62473 GPE
# Mexico City 62557 62568 GPE
# Toronto 62629 62636 GPE
# one 62693 62696 CARDINAL
# English 62743 62750 LANGUAGE
#
#  62768 62769 GPE
# Miami 62825 62830 GPE
# Goran Dragic 62837 62849 PERSON
# Mexico Citys 62855 62867 PERSON
# nearly 7,500 feet 62888 62905 QUANTITY
# more than 2,000 feet 62925 62945 QUANTITY
# Nuggets 63050 63057 ORG
#
#  63058 63059 GPE
# last weeks 63062 63072 DATE
# first 63073 63078 ORDINAL
#   63176 63177 NORP
# Brooklyns Allen Crabbe 63190 63212 PERSON
# Oklahoma 63217 63225 GPE
# Russell Westbrook 63232 63249 PERSON
# Crabbe 63338 63344 PERSON
# Westbrook 63423 63432 PERSON
#
#  63536 63537 GPE
# five 63557 63561 CARDINAL
# Rondae Hollis-Jefferson 63619 63642 PERSON
# Brooklyns 63683 63692 GPE
# fourth-quarter 63734 63748 DATE
#
#  63789 63790 GPE
# Mexico 63852 63858 GPE
#
#  63991 63992 GPE
# G League 64039 64047 ORG
# Silver 64059 64065 ORG
#
#  64071 64072 GPE
# David Sterns 64091 64103 PERSON
# Europe 64175 64181 LOC
# June 2016 64325 64334 DATE
# Mexican 64344 64351 NORP
# Televisa 64369 64377 PERSON
# ESPN 64509 64513 ORG
# NBA League Pass 64518 64533 ORG
#
#  64534 64535 GPE
# two 64566 64569 CARDINAL
# last week 64576 64585 DATE
# more than 31 million 64635 64655 CARDINAL
#
#  64670 64671 GPE
# Europe 64775 64781 LOC
# the G League 64799 64811 ORG
# Mexico 64858 64864 GPE
# N.B.A 64886 64891 GPE
#
#  64954 64955 GPE
# Llamas 64974 64980 PERSON
# first 64991 64996 ORDINAL
# G League 65009 65017 ORG
# Mexican 65049 65056 NORP
#
#  65065 65066 GPE
# seventh 65150 65157 ORDINAL
#   65180 65181 NORP
# N.F.L. 65316 65322 GPE
# Formula 65324 65331 GPE
# Major League Baseball 65340 65361 ORG
#
#  65391 65392 GPE
# Its early days 65392 65406 DATE
# Mexico City 65462 65473 GPE
#
#  65754 65755 GPE
# Najera 65819 65825 GPE
# Mavericks 65847 65856 PERSON
#
#  65886 65887 GPE
# Najera 65935 65941 PERSON
# Mexico City 66023 66034 GPE
#
#  66113 66114 GPE
# Kent Bazemore 66137 66150 ORG
#
#  66151 66152 GPE
# 3-pointer 66167 66176 CARDINAL
# 6.7 seconds 66182 66193 TIME
# the Atlanta Hawks 66208 66225 ORG
# Sunday 66232 66238 DATE
# 99-96 66244 66249 CARDINAL
# Knicks 66272 66278 ORG
#
#  66279 66280 GPE
# Bazemore 66318 66326 ORG
#
#  66449 66450 GPE
# the ‘Zen in the Art of Archery 66471 66501 WORK_OF_ART
#
#  66608 66609 GPE
# Hawks 66613 66618 ORG
# 93-87 66634 66639 DATE
# the final 2 minutes 16 seconds 66651 66681 TIME
# Mike Muscala 66683 66695 PERSON
# 3-pointer 66702 66711 CARDINAL
# 46 seconds 66717 66727 TIME
# Hawks 66745 66750 ORG
# 1 66758 66759 CARDINAL
# Kyle OQuinn 66765 66776 ORG
# Knicks 66798 66804 ORG
#
#  66821 66822 GPE
# 98-96 66878 66883 CARDINAL
# Knicks 66894 66900 ORG
# Atlanta 66986 66993 GPE
#
#  66994 66995 GPE
# one 67021 67024 CARDINAL
# two 67028 67031 CARDINAL
# Hardaway 67044 67052 ORG
# 3-pointer 67078 67087 CARDINAL
#
#  67088 67089 GPE
# Knicks 67127 67133 ORG
# Kristaps Porzingis 67134 67152 PERSON
#
#  67200 67201 GPE
# Hawks 67218 67223 ORG
# 19 67229 67231 CARDINAL
# Muscala 67240 67247 GPE
# 15 67255 67257 CARDINAL
# Taurean 67263 67270 NORP
# 13 67282 67284 CARDINAL
# 12 67307 67309 CARDINAL
# 14 67321 67323 CARDINAL
# Dennis Schroeder 67334 67350 PERSON
# 10 67357 67359 CARDINAL
# Atlanta 67371 67378 GPE
#
#  67379 67380 GPE
# 22 67397 67399 CARDINAL
# Knicks 67408 67414 ORG
# Trey Burke 67416 67426 PERSON
# 14 67433 67435 CARDINAL
# Jarrett Jack 67437 67449 PERSON
# OQuinn 67454 67460 ORG
# 11 67473 67475 CARDINAL
# Enes Kanter 67481 67492 PERSON
# 10 67507 67509 CARDINAL
# 12 67521 67523 CARDINAL
#
#  67533 67534 GPE
# 48 minutes 67564 67574 TIME
# Hawks 67576 67581 ORG
# Mike Budenholzer 67588 67604 PERSON
# Today 67611 67616 DATE
# 48 67629 67631 CARDINAL
# Knicks 67652 67658 ORG
# 2011 67784 67788 DATE
# Turkish 67814 67821 NORP
#
#  67890 67891 GPE
#
#  67935 67936 GPE
# English 68007 68014 LANGUAGE
# 15 68048 68050 CARDINAL
#
#  68122 68123 GPE
# Turkish 68145 68152 NORP
#
#  68162 68163 GPE
# Spanish 68320 68327 NORP
# Serbian 68329 68336 NORP
# Portuguese 68338 68348 NORP
#
#  68527 68528 GPE
# Jesse Thompson 68552 68566 PERSON
# Asia 68636 68640 LOC
#
#  68641 68642 GPE
# N.B.A. 68646 68652 GPE
# About a quarter 68713 68728 CARDINAL
# 62 68774 68776 CARDINAL
# 33 68803 68805 CARDINAL
#
#  68871 68872 GPE
#
#  68981 68982 GPE
# the Philadelphia 76ers 68991 69013 ORG
# seven 69059 69064 CARDINAL
# T. J. McConnell 69100 69115 PERSON
# Marco Belinelli 69144 69159 PERSON
# ...
# Knicks 976918 976924 ORG
# the years 977092 977101 DATE
# Knicks 977147 977153 ORG
#
#  977272 977273 GPE
# Knicks 977315 977321 ORG
# eight 977338 977343 CARDINAL
# nine 977358 977362 CARDINAL
# a year ago 977387 977397 DATE
# Garden 977464 977470 ORG
#
#  977584 977585 GPE
#
#  977647 977648 GPE
# INDIANAPOLIS 977648 977660 GPE
# Thaddeus Young 977662 977676 PERSON
# 20 977684 977686 CARDINAL
# seven 977702 977707 CARDINAL
# Indiana 977708 977715 GPE
# Pacers 977749 977755 PERSON
# Knicks 977780 977786 ORG
# 115 977788 977791 CARDINAL
# Monday night 977799 977811 TIME
#
#  977812 977813 GPE
# Bojan Bogdanovic 977813 977829 PERSON
# 19 977837 977839 CARDINAL
# Victor Oladipo 977851 977865 PERSON
# 16 977872 977874 CARDINAL
# Pacers 977883 977889 PERSON
# 13-11 977891 977896 DATE
# 26 977910 977912 CARDINAL
# 95 977932 977934 CARDINAL
# three quarters 977944 977958 DATE
#
#  977959 977960 GPE
# Knicks 977964 977970 ORG
# Kristaps Porzingis 978015 978033 PERSON
# 25.8 978035 978039 CARDINAL
# Tim Hardaway Jr. 978061 978077 PERSON
# 17.8 978079 978083 DATE
# second 978092 978098 ORDINAL
# Porzingis 978117 978126 PERSON
#
#  978220 978221 GPE
# Michael Beasley 978221 978236 PERSON
# Knicks 978245 978251 ORG
# 13 978257 978259 CARDINAL
#
#  978267 978268 GPE
# Pacers 978272 978278 PERSON
# second 978310 978316 ORDINAL
# 3-point 978322 978329 CARDINAL
# 11 978367 978369 CARDINAL
# 26 3-pointers 978373 978386 CARDINAL
#
#  978387 978388 GPE
# Myles Turner 978402 978414 PERSON
# the first quarter 978433 978450 DATE
# at least one 978475 978487 CARDINAL
# this season 978508 978519 DATE
# Turner 978521 978527 ORG
# third-year 978531 978541 DATE
# 39 978552 978554 CARDINAL
# second 978567 978573 ORDINAL
# as many as three 978597 978613 CARDINAL
# nine 978624 978628 CARDINAL
#
#  978635 978636 GPE
# Knicks 978649 978655 ORG
# six 978804 978807 CARDINAL
# this season 978814 978825 DATE
# 19 978848 978850 CARDINAL
# the third quarter 978862 978879 DATE
# 108 978885 978888 CARDINAL
# Pacers 978910 978916 PERSON
# Nov. 5 978920 978926 DATE
# 108-100 978930 978937 CARDINAL
# Toronto 978952 978959 GPE
# Nov. 22 978963 978970 DATE
# 28 978983 978985 CARDINAL
# the third quarter 978995 979012 DATE
# 1991-92 979048 979055 DATE
#
#  979056 979057 GPE
# Knicks 979061 979067 ORG
# Bankers Life Fieldhouse 979086 979109 ORG
# 8-27 979121 979125 DATE
#
#  979126 979127 GPE
# Pacers 979131 979137 PERSON
# 7-4 979147 979150 DATE
# six 979181 979184 CARDINAL
# Dec. 15 979232 979239 DATE
# 6 979250 979251 CARDINAL
# 120 979267 979270 CARDINAL
# 0-4 979282 979285 CARDINAL
# less than 100 979299 979312 CARDINAL
#
#  979313 979314 GPE
# 3 979476 979477 CARDINAL
#
#  979530 979531 GPE
# 7 979574 979575 CARDINAL
# Celtics 979614 979621 ORG
# Rockets 979626 979633 ORG
# 3-point 979662 979669 CARDINAL
#
#  979676 979677 GPE
# Monday night 979680 979692 TIME
# Rockets 979719 979726 NORP
# 7-for-44 979751 979759 CARDINAL
# 3 979765 979766 CARDINAL
# 16 percent 979771 979781 PERCENT
# the entire season 979810 979827 DATE
# 26 percent 979857 979867 PERCENT
# 16 979871 979873 CARDINAL
# 23 percent 979901 979911 PERCENT
# 82 regular season 979915 979932 DATE
#
#  979939 979940 GPE
# Eric Gordon 979940 979951 PERSON
# 2-for-12 979956 979964 DATE
# James Hardens 980012 980025 PERSON
#
#  980047 980048 GPE
# Harden 980048 980054 PERSON
# 3-pointers 980077 980087 CARDINAL
# this season 980104 980115 DATE
# 7-for-12 980193 980201 CARDINAL
# Utah 980219 980223 GPE
# Minnesota 980228 980237 GPE
# Monday 980255 980261 DATE
# two 980371 980374 CARDINAL
#
#  980375 980376 GPE
# the second quarter 980394 980412 DATE
# fourth 980433 980439 ORDINAL
# Rockets 980445 980452 ORG
# 27 980460 980462 CARDINAL
# 3-pointers 980472 980482 CARDINAL
# 0-for-14 980512 980520 CARDINAL
# the third quarter 980524 980541 DATE
# 14-point 980574 980582 CARDINAL
# 13-point 980593 980601 CARDINAL
#
#  980610 980611 GPE
# Rockets 980615 980622 NORP
# Chris Paul 980636 980646 PERSON
# 41 percent 980723 980733 PERCENT
# 3-point 980739 980746 CARDINAL
# 101 980764 980767 CARDINAL
#
#  980858 980859 GPE
# 3-point 980872 980879 CARDINAL
# Rockets 980929 980936 ORG
# this season 980976 980987 DATE
# 15 980996 980998 CARDINAL
# 42 981011 981013 CARDINAL
#
#  981042 981043 GPE
# that fourth quarter 981046 981065 DATE
# Harden 981098 981104 PERSON
# The Houston Chronicle 981110 981131 ORG
# Three 981133 981138 CARDINAL
# Rockets 981200 981207 ORG
# 3-point 981226 981233 CARDINAL
# the last period 981243 981258 DATE
#
#  981259 981260 GPE
# 16 981270 981272 CARDINAL
# 39 981276 981278 DATE
# 7 981292 981293 CARDINAL
# 44 981297 981299 DATE
# Mike DAntoni 981307 981319 PERSON
# Chronicle 981329 981338 ORG
#
#  981499 981500 GPE
# A night earlier 981500 981515 TIME
# Celtics 981521 981528 ORG
#
#  981568 981569 GPE
# Celtics 981573 981580 NORP
# 7-for-39 981586 981594 FAC
# 3-point 981611 981618 CARDINAL
# the night 981626 981635 TIME
# 18 percent 981640 981650 PERCENT
# second 981684 981690 ORDINAL
# all year 981697 981705 DATE
# Celtics 981717 981724 ORG
# 3-pointers 981738 981748 CARDINAL
# Rockets 981756 981763 NORP
# this season 981778 981789 DATE
# 10 981852 981854 CARDINAL
# 3-pointers 981863 981873 CARDINAL
#
#  981887 981888 GPE
# Jaylen Brown 981888 981900 PERSON
# 3-for-12 981905 981913 PRODUCT
# Sunday 981917 981923 DATE
# Celtics 981952 981959 NORP
# Terry Rozier 981985 981997 PERSON
# 0-for-10 981999 982007 CARDINAL
# 0-for-5 982046 982053 QUANTITY
#
#  982068 982069 GPE
# Celtics 982073 982080 ORG
# Cavaliers 982089 982098 ORG
# one 982102 982105 CARDINAL
# six minutes 982117 982128 TIME
# 1-for-9 982146 982153 CARDINAL
# 3-point 982159 982166 CARDINAL
# 87-79 982204 982209 CARDINAL
#
#  982210 982211 GPE
# LeBron Jamess 982217 982230 PRODUCT
# 3-pointers 982330 982340 CARDINAL
#
#  982341 982342 GPE
# Defense 982342 982349 ORG
# Rockets 982371 982378 NORP
# Celtics 982383 982390 NORP
#
#  982502 982503 GPE
# Mark Cuban 982655 982665 PERSON
# 600,000 982695 982702 MONEY
# the N.B.A. 982706 982716 ORG
# Wednesday 982720 982729 DATE
#
#  982800 982801 GPE
# Cuban 982801 982806 NORP
# around $2.6 million 982851 982870 MONEY
# January 2000 982918 982930 DATE
# Julius Erving 983065 983078 ORG
# the House Call 983082 983096 ORG
# J 983106 983107 PERSON
#
#  983169 983170 GPE
# recent seasons 983226 983240 DATE
# Adam Silver 983266 983277 PERSON
#
#  983369 983370 GPE
# Cuban 983455 983460 NORP
# 500,000 983496 983503 MONEY
# 2002 983546 983550 DATE
#
#  983551 983552 GPE
# Cuban 983572 983577 NORP
# this season 983658 983669 DATE
#
#  983689 983690 GPE
# Cuban 983728 983733 NORP
# the other night 983794 983809 TIME
#
#  983922 983923 GPE
# Adam 983959 983963 PERSON
# this summer 984089 984100 DATE
#
#  984311 984312 GPE
# 18-40 984330 984335 DATE
# third 984346 984351 ORDINAL
# Dirk Nowitzki 984403 984416 PERSON
# Hall of Famer 984434 984447 ORG
# Dennis Smith Jr. 984473 984489 PERSON
# Dallas 984493 984499 GPE
# 25 percent 984562 984572 PERCENT
# this years 984607 984617 DATE
# 2019 984637 984641 DATE
# three 984720 984725 CARDINAL
# 14 percent 984739 984749 PERCENT
# 1 984768 984769 CARDINAL
#
#  984775 984776 GPE
# Cuban 984776 984781 NORP
# Shark Tank 984816 984826 PERSON
# Mavericks 984860 984869 PERSON
# Tuesday 985045 985052 DATE
# Terdema Ussery 985179 985193 PERSON
#
#  985279 985280 GPE
# PLAYA 985280 985285 ORG
# Calif. 985293 985299 GPE
# the Los Angeles Clippers 985321 985345 ORG
# Milos Teodosic 985401 985415 PERSON
#
#  985416 985417 GPE
#
#  985440 985441 GPE
# Serbian 985493 985500 NORP
# the age of 30 985673 985686 DATE
# Teodosic 985735 985743 ORG
# Clippers 985756 985764 ORG
# Sam Dekker 985774 985784 PERSON
# September 985798 985807 DATE
# Teodosic 985897 985905 ORG
#
#  985947 985948 GPE
#
#  985983 985984 GPE
# Clippers 986009 986017 NORP
#  Teodosics 986133 986143 ORG
# Teodosic 986206 986214 FAC
#
#  986406 986407 GPE
# Teodosic 986445 986453 ORG
# 10 986568 986570 CARDINAL
# a day 986580 986585 DATE
#
#  986611 986612 GPE
# Milos 986651 986656 NORP
# YouTube 986714 986721 NORP
# daily 986913 986918 DATE
# Teodosic 987034 987042 ORG
# Clippers 987059 987067 NORP
#
#  987075 987076 GPE
# Dekker 987114 987120 PERSON
#
#  987126 987127 GPE
# Clippers 987146 987154 ORG
# Chris Paul 987186 987196 PERSON
# Houston 987214 987221 GPE
# last June 987222 987231 DATE
# Teodosic 987245 987253 ORG
# two-year 987259 987267 DATE
# $12.3 million 987279 987292 MONEY
# Basketball Without Borders 987299 987325 ORG
# Israel 987336 987342 GPE
# August 987370 987376 DATE
# Dekker 987378 987384 ORG
# Israeli 987416 987423 NORP
#
#  987511 987512 GPE
# Dekker 987535 987541 PERSON
#
#  987586 987587 GPE
# Teodosic 987645 987653 ORG
# annual 987676 987682 DATE
# Rising Stars 987683 987695 WORK_OF_ART
# second-year 987722 987733 DATE
# next Friday 987789 987800 DATE
# night 987801 987806 TIME
# Los Angeles 987840 987851 GPE
# this season 987852 987863 DATE
# Teodosic 987868 987876 ORG
# Clippers 988018 988026 PERSON
# 17 988036 988038 CARDINAL
# 11 988065 988067 CARDINAL
# Monday 988098 988104 DATE
# nights 988105 988111 TIME
# Brooklyn 988120 988128 GPE
# L.A. 988130 988134 GPE
# plus-5.8 988151 988159 ORG
# 100 possessions 988171 988186 QUANTITY
# this season 988194 988205 DATE
#
#  988255 988256 GPE
# Teodosic 988256 988264 ORG
#
#  988308 988309 GPE
# 30 years old 988378 988390 DATE
#
#  988454 988455 GPE
# 26 988467 988469 CARDINAL
# Teodosic 988471 988479 ORG
# the Memphis Grizzlies 988515 988536 ORG
# the summer of 2013 988580 988598 DATE
# the United States 988644 988661 GPE
# Euroleague 988677 988687 ORG
# another three years 988732 988751 DATE
# European 988761 988769 NORP
# Teodosic 988803 988811 ORG
# Moscow 988821 988827 GPE
# second 988835 988841 ORDINAL
# 2016 988904 988908 DATE
#
#  988909 988910 GPE
# second 988932 988938 ORDINAL
# three-year 988939 988949 DATE
# the 2016-17 season 988970 988988 DATE
# Atlantic 989104 989112 LOC
# U.S. 989177 989181 GPE
#
#  989189 989190 GPE
# Teodosic 989190 989198 ORG
# Euroleague 989256 989266 ORG
# 2010 989310 989314 DATE
# Serbia 989341 989347 GPE
# United States 989392 989405 GPE
# 2014 989418 989422 DATE
# FIBA World Cup 989423 989437 EVENT
# 2016 989446 989450 DATE
# Rio Olympics 989451 989463 EVENT
# Teodosic 989514 989522 ORG
# Clippers 989542 989550 ORG
#
#  989551 989552 GPE
# first-year 989706 989716 DATE
# Dekker 989808 989814 PERSON
# Teodosic 989823 989831 ORG
#
#  989870 989871 GPE
# Teodosic 989911 989919 ORG
# Euroleague 990114 990124 ORG
# earlier 990147 990154 DATE
#
#  990155 990156 GPE
# first 990168 990173 ORDINAL
# two 990203 990206 CARDINAL
# Europe 990227 990233 LOC
# Teodosic 990235 990243 ORG
#
#  990529 990530 GPE
# Clipper 990589 990596 ORG
# 38.2 percent 990653 990665 PERCENT
# Teodosic 990729 990737 ORG
# 25 990754 990756 CARDINAL
# Doc Rivers 990811 990821 PERSON
# first 990822 990827 ORDINAL
# five 990828 990832 CARDINAL
# Patrick Beverley 990845 990861 PERSON
# Olympiacos 990894 990904 FAC
# Greece 990908 990914 GPE
# this season 990940 990951 DATE
# November 990974 990982 DATE
# Teodosic 991001 991009 ORG
# 28 991031 991033 CARDINAL
#
#  991104 991105 GPE
# the years 991178 991187 DATE
# Mike Krzyzewski 991200 991215 PERSON
# Krzyzewski 991293 991303 PERSON
# Team USA 991316 991324 ORG
# the Rio Games 991349 991362 EVENT
#
#  991389 991390 GPE
# Messina 991397 991404 LOC
# San Antonio Spurs 991438 991455 LOC
# Teodosic 991471 991479 ORG
# Moscow 991488 991494 GPE
# two seasons 991499 991510 DATE
# Vincent van Gogh 991549 991565 PERSON
# their CSKA days 991569 991584 DATE
#
#  991585 991586 GPE
# Messina 991641 991648 PERSON
# Teodosic 991699 991707 GPE
# the Pete Maravich 991711 991728 ORG
# European 991732 991740 NORP
#
#  991752 991753 GPE
# Messina 991829 991836 PERSON
# one 991994 991997 CARDINAL
#
#  992039 992040 GPE
# Clippers 992044 992052 ORG
# Teodosic 992061 992069 ORG
# Blake Griffin 992130 992143 PERSON
# Detroit 992147 992154 GPE
# Jan. 29 992158 992165 DATE
# one 992363 992366 CARDINAL
# three 992370 992375 CARDINAL
#
#  992406 992407 GPE
# Serbians 992511 992519 NORP
# Griffin 992535 992542 NORP
# Teodosic 992547 992555 FAC
# September 992608 992617 DATE
# Dekker 992632 992638 PERSON
# San Diego 992642 992651 GPE
# McDonalds 992675 992684 ORG
# some morning 992735 992747 TIME
#
#  992759 992760 GPE
# Dekker 992763 992769 PERSON
# Teodosic 992780 992788 ORG
# two 992799 992802 CARDINAL
# that hour 992934 992943 TIME
#
#  992944 992945 GPE
# Dekker 993014 993020 PERSON
# Milos 993027 993032 PERSON
#
#  993081 993082 GPE
# Teodosic 993082 993090 ORG
#
#  993118 993119 GPE
# Teodosic 993254 993262 ORG
# European 993278 993286 NORP
# Teodosic 993299 993307 ORG
# Dekker 993322 993328 PERSON
#
#  993449 993450 GPE
# Dekker 993467 993473 PERSON
# Milos 993502 993507 PERSON
# Beatle 993667 993673 ORG
#
#  993674 993675 GPE
# Teodosic 993701 993709 ORG
#
#  993790 993791 GPE
# Teodosic 993811 993819 ORG
#
#  993891 993892 GPE
#   993967 993968 NORP
#
#  993980 993981 GPE
# American 994015 994023 NORP
# a morning 994162 994171 TIME
# Teodosic 994221 994229 GPE
# A.C. Milan 994236 994246 ORG
# Liverpool 994251 994260 GPE
# Serbian 994272 994279 NORP
# Dejan Bodiroga 994300 994314 PERSON
# one 994376 994379 CARDINAL
#
#  994458 994459 GPE
# two 994476 994479 CARDINAL
#
#  994502 994503 GPE
# Teodosic 994545 994553 ORG
#
#  994675 994676 GPE
# Meek Mill 994676 994685 PERSON
# Philadelphia 994691 994703 GPE
# decade-old 994736 994746 DATE
# Tuesday 994849 994856 DATE
# the Pennsylvania Supreme Court 994863 994893 ORG
#
#  994914 994915 GPE
# Meek 994942 994946 ORG
# a single day 994996 995008 DATE
# Joe Tacopina 995030 995042 PERSON
#
#  995064 995065 GPE
# Meek Mill 995065 995074 PERSON
# Robert Rahmeek Williams 995096 995119 PERSON
# Chester 995164 995171 GPE
# Pa. 995173 995176 GPE
# 2008 995197 995201 DATE
# eight months 995266 995278 DATE
# five years 995326 995336 DATE
#
#  995384 995385 GPE
# November 995388 995396 DATE
# Genece E. Brinkley 995404 995422 PERSON
# two to four years 995440 995457 DATE
# two 995501 995504 CARDINAL
# one 995514 995517 CARDINAL
# New York 995592 995600 GPE
#
#  995601 995602 GPE
# last week 995619 995628 DATE
#
#  995748 995749 GPE
# Meek Mill 995967 995976 PERSON
#
#  996171 996172 GPE
# November 996254 996262 DATE
#  999889 999890 GPE
# DeShields 999900 999909 ORG

# %% [markdown]
# So this does a pretty good job but is also slow. Let's analysis how accurate the less precise textblob versions are:

# %%
team_names = pd.read_csv('../player_stats/team_names.csv')

# %% [markdown]
# Note that this data frame contains names of all teams along with number of wins this season and the round of playoffs.

# %%
team_names.head()
# Out:
#         Name  Wins  Playoffs Conference  New York Team          City
# 0     Lakers    35         0          W              0   Los Angeles
# 1  Cavaliers    50         4          E              0     Cleveland
# 2   Warriors    58         5          W              0  Golden State
# 3    Celtics    55         3          E              0        Boston
# 4      Spurs    47         1          W              0   San Antonio

# %%
playoff_dict = {0:'DNQ',1:'First Round',2:'Second Round',3:'Conference Finals',4:'NBA Finals',5:'Champion'}

# %%
names = list(team_names['Name'])

# %% [markdown]
# Prediction with TextBlob tags:

# %%
for name in names:
    print('{} has {} occurrences in corpus'.format(name,c2[name.lower()]))
# Out:
# Lakers has 103 occurrences in corpus
# Cavaliers has 370 occurrences in corpus
# Warriors has 521 occurrences in corpus
# Celtics has 302 occurrences in corpus
# Spurs has 108 occurrences in corpus
# 76ers has 186 occurrences in corpus
# Knicks has 590 occurrences in corpus
# Bulls has 28 occurrences in corpus
# Rockets has 296 occurrences in corpus
# Raptors has 153 occurrences in corpus
# Mavericks has 60 occurrences in corpus
# Thunder has 67 occurrences in corpus
# Suns has 41 occurrences in corpus
# Heat has 75 occurrences in corpus
# Hawks has 32 occurrences in corpus
# Timberwolves has 46 occurrences in corpus
# Hornets has 31 occurrences in corpus
# Clippers has 99 occurrences in corpus
# Pistons has 37 occurrences in corpus
# Pacers has 91 occurrences in corpus
# Blazers has 44 occurrences in corpus
# Bucks has 62 occurrences in corpus
# Wizards has 61 occurrences in corpus
# Magic has 45 occurrences in corpus
# Nets has 146 occurrences in corpus
# Grizzlies has 29 occurrences in corpus
# Kings has 52 occurrences in corpus
# Nuggets has 38 occurrences in corpus
# Jazz has 65 occurrences in corpus
# Pelicans has 106 occurrences in corpus

# %%
team_names['noun_occurrences'] = [c2[name.lower()] for name in names]

# %% [markdown]
# Picking out these specific strings:

# %%
for name in names:
    print('{} has {} occurrences in corpus'.format(name,corpus.count(name)))
# Out:
# Lakers has 103 occurrences in corpus
# Cavaliers has 369 occurrences in corpus
# Warriors has 525 occurrences in corpus
# Celtics has 297 occurrences in corpus
# Spurs has 109 occurrences in corpus
# 76ers has 195 occurrences in corpus
# Knicks has 591 occurrences in corpus
# Bulls has 28 occurrences in corpus
# Rockets has 296 occurrences in corpus
# Raptors has 150 occurrences in corpus
# Mavericks has 60 occurrences in corpus
# Thunder has 77 occurrences in corpus
# Suns has 42 occurrences in corpus
# Heat has 71 occurrences in corpus
# Hawks has 32 occurrences in corpus
# Timberwolves has 52 occurrences in corpus
# Hornets has 32 occurrences in corpus
# Clippers has 100 occurrences in corpus
# Pistons has 37 occurrences in corpus
# Pacers has 90 occurrences in corpus
# Blazers has 42 occurrences in corpus
# Bucks has 58 occurrences in corpus
# Wizards has 58 occurrences in corpus
# Magic has 42 occurrences in corpus
# Nets has 150 occurrences in corpus
# Grizzlies has 29 occurrences in corpus
# Kings has 52 occurrences in corpus
# Nuggets has 38 occurrences in corpus
# Jazz has 51 occurrences in corpus
# Pelicans has 104 occurrences in corpus

# %%
team_names['raw_occurrences'] = [corpus.count(name) for name in names]

# %%
team_names['% difference'] = ((team_names.raw_occurrences - team_names.noun_occurrences) / team_names.raw_occurrences)*100

# %%
team_names.sort_values(['noun_occurrences'],ascending=False)
# Out:
#             Name  Wins  Playoffs Conference  New York Team           City  \
# 6         Knicks    29         0          E              1       New York
# 2       Warriors    58         5          W              0   Golden State
# 1      Cavaliers    50         4          E              0      Cleveland
# 3        Celtics    55         3          E              0         Boston
# 8        Rockets    65         3          W              0        Houston
# 5          76ers    52         2          E              0   Philadelphia
# 9        Raptors    59         2          E              0        Toronto
# 24          Nets    28         0          E              1       Brooklyn
# 4          Spurs    47         1          W              0    San Antonio
# 29      Pelicans    48         2          W              0    New Orleans
# 0         Lakers    35         0          W              0    Los Angeles
# 17      Clippers    42         0          W              0    Los Angeles
# 19        Pacers    48         1          E              0        Indiana
# 13          Heat    44         1          E              0          Miami
# 11       Thunder    48         1          W              0  Oklahoma City
# 28          Jazz    48         2          W              0           Utah
# 21         Bucks    44         1          E              0      Milwaukee
# 22       Wizards    43         0          E              0     Washington
# 10     Mavericks    24         0          W              0         Dallas
# 26         Kings    27         0          W              0     Sacramento
# 15  Timberwolves    47         1          W              0      Minnesota
# 23         Magic    25         0          E              0        Orlando
# 20       Blazers    49         1          W              0       Portland
# 12          Suns    21         0          W              0        Phoenix
# 27       Nuggets    46         0          W              0         Denver
# 18       Pistons    39         0          E              0        Detroit
# 14         Hawks    24         0          E              0        Atlanta
# 16       Hornets    36         0          E              0      Charlotte
# 25     Grizzlies    22         0          E              0        Memphis
# 7          Bulls    27         0          E              0        Chicago
#
#     noun_occurrences  raw_occurrences  % difference
# 6                590              591      0.169205
# 2                521              525      0.761905
# 1                370              369     -0.271003
# 3                302              297     -1.683502
# 8                296              296      0.000000
# 5                186              195      4.615385
# 9                153              150     -2.000000
# 24               146              150      2.666667
# 4                108              109      0.917431
# 29               106              104     -1.923077
# 0                103              103      0.000000
# 17                99              100      1.000000
# 19                91               90     -1.111111
# 13                75               71     -5.633803
# 11                67               77     12.987013
# 28                65               51    -27.450980
# 21                62               58     -6.896552
# 22                61               58     -5.172414
# 10                60               60      0.000000
# 26                52               52      0.000000
# 15                46               52     11.538462
# 23                45               42     -7.142857
# 20                44               42     -4.761905
# 12                41               42      2.380952
# 27                38               38      0.000000
# 18                37               37      0.000000
# 14                32               32      0.000000
# 16                31               32      3.125000
# 25                29               29      0.000000
# 7                 28               28      0.000000

# %% [markdown]
# So from this analysis we find that there is little discrepancy between the number of raw strings matching the team names in the text and the number found by restricting ourselves to TextBlob nouns. This seems like a sensible way to proceed with our analysis.

# %%
team_names.to_csv('NER_vs_raw_strings.csv',index=False)

# %% [markdown]
# # 4. Comparing Sentiment Classifiers:

# %% [markdown]
# Read in files:

# %%
articles_list = pd.read_csv('../nyt_scrape/articles_list_w_date.csv',parse_dates=['date'])

# %%
file_title = articles_list.article_urls.apply(lambda x : x.replace("/","").replace(".",""))
article_date = articles_list.date

title_date_dict = dict(zip(file_title,article_date))

# %%
title_text_dict = dict()

for article in file_title:
    with open(f'../nyt_scrape/articles/{article}.txt') as f:
        title_text_dict[article] = f.read().replace('’','').replace('”','').replace('“','').replace('—','').split('\n')

# %%
para = TextBlob(title_text_dict[file_title[0]][0])

# %%
print(para, para.sentiment)
# Out:
# The Golden State Warriors have ruined basketball. Sentiment(polarity=0.3, subjectivity=0.5)

# %% [markdown]
# At first glance this sentiment analysis looks to be quite poor - we would hope this paragraph would register negative sentiment.

# %% [markdown]
# **Vader Sentiment:**

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
vader = SentimentIntensityAnalyzer()

# %%
vader.polarity_scores(para)
# Out:
# {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'compound': -0.4767}

# %%
for para in title_text_dict[file_title[25]][:5]:
    print(f'{para}\nTextBlob Sentiment Scores:{TextBlob(para).sentiment}\nVader Sentiment Scores:{vader.polarity_scores(para)}\n\n')
# Out:
# BOSTON  With a little help from his friends, though not that much, LeBron James dazzled once again in a playoff elimination game, sending the Cavaliers back to the N.B.A. finals on Sunday night and keeping himself in a Cleveland uniform for at least another two weeks.
# TextBlob Sentiment Scores:Sentiment(polarity=-0.1375, subjectivity=0.3)
# Vader Sentiment Scores:{'neg': 0.0, 'neu': 0.882, 'pos': 0.118, 'compound': 0.6712}
#
#
# In a game that looked bleak at the outset, with the Cavaliers playing without the injured Kevin Love, James powered an offense that started the game atrociously and then did just enough to break the upstart hearts of the young Boston Celtics, 87-79, in Game 7 of the Eastern Conference finals.
# TextBlob Sentiment Scores:Sentiment(polarity=-0.2875, subjectivity=0.5875)
# Vader Sentiment Scores:{'neg': 0.036, 'neu': 0.814, 'pos': 0.149, 'compound': 0.7398}
#
#
# James played all 48 minutes and finished with 35 points, 15 rebounds and 9 assists, missing a triple-double only because the Cavaliers missed 26 of 35 3-pointers, many of them uncontested shots set up by pinpoint passes from James.
# TextBlob Sentiment Scores:Sentiment(polarity=0.09999999999999999, subjectivity=0.5166666666666667)
# Vader Sentiment Scores:{'neg': 0.108, 'neu': 0.833, 'pos': 0.059, 'compound': -0.25}
#
#
# Fortunately for the Cavaliers, the Celtics were even worse, shooting 7 for 39 from behind the 3-point line. As a result, Bostons somewhat improbable playoff run, which came with two All-Star players  Gordon Hayward and Kyrie Irving  lost to injury, ended in stark disappointment. And with James triumphant once again.
# TextBlob Sentiment Scores:Sentiment(polarity=-0.24000000000000005, subjectivity=0.5999999999999999)
# Vader Sentiment Scores:{'neg': 0.199, 'neu': 0.743, 'pos': 0.059, 'compound': -0.7964}
#
#
# Weve been counted out for a long time this season, a sweat-drenched James said while slipping on his 2018 N.B.A. finals cap. After pointing out that the Celtics had been undefeated at home in the playoffs until Sunday, James saluted the forward Jeff Green, who started in Loves place and contributed 19 points and 8 rebounds for Cleveland.
# TextBlob Sentiment Scores:Sentiment(polarity=-0.11666666666666668, subjectivity=0.26666666666666666)
# Vader Sentiment Scores:{'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.5719}

# %% [markdown]
# On balance, Vader Sentiment appears to be more accurately capturing the sentiment of the article.
